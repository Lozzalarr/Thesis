# %% [markdown]
# # Convert PASCAL Objects from roboflow to ESRI

# %% [markdown]
# ### Organise Roboflow Files

# %%
# steps:
    #1: rename the train folder to images
    #2: move the xml files from the images folder into another folder at the root directory under the name labels
    #2: delete the other roboflow files...

import os
import shutil

# put your roboflow PSCAL VOC training data folder in the same directory as this notbook

labels_folder_name = './TwoClass_test/'

input_dir = os.path.join(labels_folder_name, 'train')
image_dir = os.path.join(labels_folder_name, 'images')
label_dir = os.path.join(labels_folder_name, 'labels')

if os.path.exists(input_dir):
    os.rename(input_dir, image_dir)
    os.makedirs(label_dir)

    # Loop through the source directory
    for file_name in os.listdir(image_dir):
        if file_name.endswith('.xml'):
            # Construct the full path of the source file
            source_file = os.path.join(image_dir, file_name)
            
            # Move the XML file to the destination directory
            shutil.move(source_file, label_dir)

# %% [markdown]
# #### Rename the files
#
# to clean up the roboflow naming convention

# %%
# Define the paths to the image and label folders
image_dir = './TwoClass_test/images'
label_dir = './TwoClass_test/labels'

# Get the list of files in the image folder
image_files = sorted([f for f in os.listdir(image_dir) if f.endswith('.jpg')])

# Get the list of files in the label folders
label_files_1 = sorted([f for f in os.listdir(label_dir) if f.endswith('.xml')])

# Check if the number of files in each folder is the same
if len(image_files) != len(label_files_1):
    print("Error: The number of files in the folders doesn't match.")
    exit()

# Rename the files
for i, (image_file, label_file_1) in enumerate(zip(image_files, label_files_1), start=1):
    # Generate the new file names
    new_image_name = f"{i:05}.jpg"
    new_label_name_1 = f"{i:05}.xml"


    # Rename the files in each folder
    os.rename(os.path.join(image_dir, image_file), os.path.join(image_dir, new_image_name))
    os.rename(os.path.join(label_dir, label_file_1), os.path.join(label_dir, new_label_name_1))

    print(f"Renamed: {image_file} to {new_image_name}")
    print(f"Renamed: {label_file_1} to {new_label_name_1}")
# Out:
# Renamed: 00006_jpg.rf.826d039bf454274e3939667e403940a0.jpg to 00001.jpg
# Renamed: 00006_jpg.rf.826d039bf454274e3939667e403940a0.xml to 00001.xml
# Renamed: 00009_jpg.rf.6eee93ee2d282f415de90017e292edc0.jpg to 00002.jpg
# Renamed: 00009_jpg.rf.6eee93ee2d282f415de90017e292edc0.xml to 00002.xml
# Renamed: 00022_jpg.rf.f6298c75bc9500cd36a289d9211a8da9.jpg to 00003.jpg
# Renamed: 00022_jpg.rf.f6298c75bc9500cd36a289d9211a8da9.xml to 00003.xml
# Renamed: 00024_jpg.rf.021ba231069899d79ef266a729db7d5e.jpg to 00004.jpg
# Renamed: 00024_jpg.rf.021ba231069899d79ef266a729db7d5e.xml to 00004.xml
# Renamed: 00025_jpg.rf.8b51c9fda56c954c33e337a73d047721.jpg to 00005.jpg
# Renamed: 00025_jpg.rf.8b51c9fda56c954c33e337a73d047721.xml to 00005.xml
# Renamed: 00027_jpg.rf.45177bde81e58ab4834f4a0650037730.jpg to 00006.jpg
# Renamed: 00027_jpg.rf.45177bde81e58ab4834f4a0650037730.xml to 00006.xml
# Renamed: 00030_jpg.rf.efb3dc1bd24e301b5bed9d6fd9a57599.jpg to 00007.jpg
# Renamed: 00030_jpg.rf.efb3dc1bd24e301b5bed9d6fd9a57599.xml to 00007.xml
# Renamed: 00049_jpg.rf.8a574aaa912ad9025e1063d3b271db31.jpg to 00008.jpg
# Renamed: 00049_jpg.rf.8a574aaa912ad9025e1063d3b271db31.xml to 00008.xml
# Renamed: 00051_jpg.rf.416519c3b89c410991fedaad4bf35834.jpg to 00009.jpg
# Renamed: 00051_jpg.rf.416519c3b89c410991fedaad4bf35834.xml to 00009.xml
# Renamed: 00088_jpg.rf.9d318ec0ec836c1423519729d6346109.jpg to 00010.jpg
# Renamed: 00088_jpg.rf.9d318ec0ec836c1423519729d6346109.xml to 00010.xml
# Renamed: 00089_jpg.rf.2191d6e9ee7a5d141927c050fd195596.jpg to 00011.jpg
# Renamed: 00089_jpg.rf.2191d6e9ee7a5d141927c050fd195596.xml to 00011.xml
# Renamed: 00098_jpg.rf.2fcd2d7220f1bc10090cd620c849f0ca.jpg to 00012.jpg
# Renamed: 00098_jpg.rf.2fcd2d7220f1bc10090cd620c849f0ca.xml to 00012.xml
# Renamed: 00101_jpg.rf.a7106b563c5b4b12486c8f126bd6f9c7.jpg to 00013.jpg
# Renamed: 00101_jpg.rf.a7106b563c5b4b12486c8f126bd6f9c7.xml to 00013.xml
# Renamed: 00111_jpg.rf.637b578bee3ad73329e7ff908040607b.jpg to 00014.jpg
# Renamed: 00111_jpg.rf.637b578bee3ad73329e7ff908040607b.xml to 00014.xml
# Renamed: 00115_jpg.rf.35c4aeb3c93bab8ffb10c33d489ac201.jpg to 00015.jpg
# Renamed: 00115_jpg.rf.35c4aeb3c93bab8ffb10c33d489ac201.xml to 00015.xml
# Renamed: 00160_jpg.rf.053f51b0e7bd5f7b35513a987a0367aa.jpg to 00016.jpg
# Renamed: 00160_jpg.rf.053f51b0e7bd5f7b35513a987a0367aa.xml to 00016.xml
# Renamed: 00166_jpg.rf.1a057e9621afcaf711ea34a25cbf1753.jpg to 00017.jpg
# Renamed: 00166_jpg.rf.1a057e9621afcaf711ea34a25cbf1753.xml to 00017.xml
# Renamed: 00174_jpg.rf.f396d9e7b699c806281f9204e1f7fa54.jpg to 00018.jpg
# Renamed: 00174_jpg.rf.f396d9e7b699c806281f9204e1f7fa54.xml to 00018.xml
# Renamed: 00191_jpg.rf.0edd552e5eeb6df2432ff08435cede28.jpg to 00019.jpg
# Renamed: 00191_jpg.rf.0edd552e5eeb6df2432ff08435cede28.xml to 00019.xml
# Renamed: 00250_jpg.rf.add9e7aaaa894d7a1b650f44d05a67cd.jpg to 00020.jpg
# Renamed: 00250_jpg.rf.add9e7aaaa894d7a1b650f44d05a67cd.xml to 00020.xml
# Renamed: 00254_jpg.rf.62d2ddff2eb608d5715978b2bc0e3ecb.jpg to 00021.jpg
# Renamed: 00254_jpg.rf.62d2ddff2eb608d5715978b2bc0e3ecb.xml to 00021.xml
# Renamed: 00259_jpg.rf.1b396eec1df74046beb547d8e2f9e80c.jpg to 00022.jpg
# Renamed: 00259_jpg.rf.1b396eec1df74046beb547d8e2f9e80c.xml to 00022.xml
# Renamed: 00270_jpg.rf.a9b41a4884e366ac221bf3256b6997dc.jpg to 00023.jpg
# Renamed: 00270_jpg.rf.a9b41a4884e366ac221bf3256b6997dc.xml to 00023.xml
# Renamed: 00288_jpg.rf.50dd09fd4acc09dd94a2032ab109b660.jpg to 00024.jpg
# Renamed: 00288_jpg.rf.50dd09fd4acc09dd94a2032ab109b660.xml to 00024.xml
# Renamed: 00289_jpg.rf.2bd4bd3a296122b711e7fd06f86663fa.jpg to 00025.jpg
# Renamed: 00289_jpg.rf.2bd4bd3a296122b711e7fd06f86663fa.xml to 00025.xml
# Renamed: 00298_jpg.rf.3e17374856c8b4f543e79fc63bbe71f5.jpg to 00026.jpg
# Renamed: 00298_jpg.rf.3e17374856c8b4f543e79fc63bbe71f5.xml to 00026.xml
# Renamed: 00299_jpg.rf.df890c0cfed9a35c11c264d0dc457349.jpg to 00027.jpg
# Renamed: 00299_jpg.rf.df890c0cfed9a35c11c264d0dc457349.xml to 00027.xml
# Renamed: 00320_jpg.rf.e792db717a42bc3b7eeb52fb07f4d211.jpg to 00028.jpg
# Renamed: 00320_jpg.rf.e792db717a42bc3b7eeb52fb07f4d211.xml to 00028.xml
# Renamed: 00326_jpg.rf.9233276388f250bfbe49cfb26829a65a.jpg to 00029.jpg
# Renamed: 00326_jpg.rf.9233276388f250bfbe49cfb26829a65a.xml to 00029.xml
# Renamed: 00348_jpg.rf.f121e61951276a8f3dbe4f7f3c32a76d.jpg to 00030.jpg
# Renamed: 00348_jpg.rf.f121e61951276a8f3dbe4f7f3c32a76d.xml to 00030.xml
# Renamed: 00349_jpg.rf.7c01663c7f23130efcc16b41db839837.jpg to 00031.jpg
# Renamed: 00349_jpg.rf.7c01663c7f23130efcc16b41db839837.xml to 00031.xml
# Renamed: 00353_jpg.rf.a06b5be58a2bfa71e6d2dfa02d689499.jpg to 00032.jpg
# Renamed: 00353_jpg.rf.a06b5be58a2bfa71e6d2dfa02d689499.xml to 00032.xml
# Renamed: 00374_jpg.rf.64c221faa5f4d674a937c013eb0c5aa4.jpg to 00033.jpg
# Renamed: 00374_jpg.rf.64c221faa5f4d674a937c013eb0c5aa4.xml to 00033.xml
# Renamed: 00375_jpg.rf.ffe1cc01230ac62a72c23f748b3c0a01.jpg to 00034.jpg
# Renamed: 00375_jpg.rf.ffe1cc01230ac62a72c23f748b3c0a01.xml to 00034.xml
# Renamed: 00384_jpg.rf.59a18c8dd8d3c580630d1add174a3959.jpg to 00035.jpg
# Renamed: 00384_jpg.rf.59a18c8dd8d3c580630d1add174a3959.xml to 00035.xml
# Renamed: 00404_jpg.rf.fb50ea4e9232c3775732f5408d50b56c.jpg to 00036.jpg
# Renamed: 00404_jpg.rf.fb50ea4e9232c3775732f5408d50b56c.xml to 00036.xml
# Renamed: 00455_jpg.rf.a37d59d7f4e44dc3567347c48e01c423.jpg to 00037.jpg
# Renamed: 00455_jpg.rf.a37d59d7f4e44dc3567347c48e01c423.xml to 00037.xml
# Renamed: 00463_jpg.rf.ead99ad523a2894b00349f9eb6d0b07d.jpg to 00038.jpg
# Renamed: 00463_jpg.rf.ead99ad523a2894b00349f9eb6d0b07d.xml to 00038.xml
# Renamed: 00466_jpg.rf.7b2bfe835d95889e091d6c8100f6d24e.jpg to 00039.jpg
# Renamed: 00466_jpg.rf.7b2bfe835d95889e091d6c8100f6d24e.xml to 00039.xml
# Renamed: 00476_jpg.rf.958dd7b0c716fd2eb9f10defb8bd835a.jpg to 00040.jpg
# Renamed: 00476_jpg.rf.958dd7b0c716fd2eb9f10defb8bd835a.xml to 00040.xml
# Renamed: 00490_jpg.rf.efaf099d914355ff72e1a34966b83176.jpg to 00041.jpg
# Renamed: 00490_jpg.rf.efaf099d914355ff72e1a34966b83176.xml to 00041.xml
# Renamed: 00491_jpg.rf.2372882dc2fb845a9732292187033cf6.jpg to 00042.jpg
# Renamed: 00491_jpg.rf.2372882dc2fb845a9732292187033cf6.xml to 00042.xml
# Renamed: 00494_jpg.rf.05ec88ee40ff7dfc35fa21d126f217d5.jpg to 00043.jpg
# Renamed: 00494_jpg.rf.05ec88ee40ff7dfc35fa21d126f217d5.xml to 00043.xml
# Renamed: 00498_jpg.rf.0769e90d83a2c0a7061f4d473649a4ce.jpg to 00044.jpg
# Renamed: 00498_jpg.rf.0769e90d83a2c0a7061f4d473649a4ce.xml to 00044.xml
# Renamed: 00509_jpg.rf.7d19cdfd31114da9ef70140d3914310f.jpg to 00045.jpg
# Renamed: 00509_jpg.rf.7d19cdfd31114da9ef70140d3914310f.xml to 00045.xml
# Renamed: 00521_jpg.rf.649c28e130db7e9d1dc365eda17bd4a9.jpg to 00046.jpg
# Renamed: 00521_jpg.rf.649c28e130db7e9d1dc365eda17bd4a9.xml to 00046.xml
# Renamed: 00532_jpg.rf.e9dfe36321221e4a2b2ad5391d83185c.jpg to 00047.jpg
# Renamed: 00532_jpg.rf.e9dfe36321221e4a2b2ad5391d83185c.xml to 00047.xml
# Renamed: 00542_jpg.rf.bb06dfdf30a771abc6111e4dc66b99a8.jpg to 00048.jpg
# Renamed: 00542_jpg.rf.bb06dfdf30a771abc6111e4dc66b99a8.xml to 00048.xml
# Renamed: 00549_jpg.rf.58d5eafd6388a955b0f411a5fb6fb06f.jpg to 00049.jpg
# Renamed: 00549_jpg.rf.58d5eafd6388a955b0f411a5fb6fb06f.xml to 00049.xml
# Renamed: 00555_jpg.rf.f3031bef942b3541a2278440849a7e7e.jpg to 00050.jpg
# Renamed: 00555_jpg.rf.f3031bef942b3541a2278440849a7e7e.xml to 00050.xml
# Renamed: 00558_jpg.rf.d9464d71f8a98e248705ebe824ee62f0.jpg to 00051.jpg
# Renamed: 00558_jpg.rf.d9464d71f8a98e248705ebe824ee62f0.xml to 00051.xml
# Renamed: 00584_jpg.rf.c4b0615921a61bb376e78ad804e24b97.jpg to 00052.jpg
# Renamed: 00584_jpg.rf.c4b0615921a61bb376e78ad804e24b97.xml to 00052.xml
# Renamed: 00615_jpg.rf.4bc4a3dee013c72c15ac8681e5ce40e3.jpg to 00053.jpg
# Renamed: 00615_jpg.rf.4bc4a3dee013c72c15ac8681e5ce40e3.xml to 00053.xml
# Renamed: 00621_jpg.rf.3d4e7ef92de631a01b6890607b77691d.jpg to 00054.jpg
# Renamed: 00621_jpg.rf.3d4e7ef92de631a01b6890607b77691d.xml to 00054.xml
# Renamed: 00632_jpg.rf.da183c8ef401870fcd09e09fe9510a0d.jpg to 00055.jpg
# Renamed: 00632_jpg.rf.da183c8ef401870fcd09e09fe9510a0d.xml to 00055.xml
# Renamed: 00682_jpg.rf.94b8daf0e03deca23fcba07bc48350e0.jpg to 00056.jpg
# Renamed: 00682_jpg.rf.94b8daf0e03deca23fcba07bc48350e0.xml to 00056.xml
# Renamed: 00701_jpg.rf.5161fa16ed4cecf10762ea5c637da310.jpg to 00057.jpg
# Renamed: 00701_jpg.rf.5161fa16ed4cecf10762ea5c637da310.xml to 00057.xml
# Renamed: 00707_jpg.rf.d61baabbcf9b45514a8739fca9846d04.jpg to 00058.jpg
# Renamed: 00707_jpg.rf.d61baabbcf9b45514a8739fca9846d04.xml to 00058.xml
# Renamed: 00742_jpg.rf.e5eb8951d7b370269de95286202e83b7.jpg to 00059.jpg
# Renamed: 00742_jpg.rf.e5eb8951d7b370269de95286202e83b7.xml to 00059.xml
# Renamed: 00756_jpg.rf.08d73bac105e1e618b8c7c7889aa76f8.jpg to 00060.jpg
# Renamed: 00756_jpg.rf.08d73bac105e1e618b8c7c7889aa76f8.xml to 00060.xml
# Renamed: 00760_jpg.rf.68dbdcbac5ee57cc4cac1ffacb3c3327.jpg to 00061.jpg
# Renamed: 00760_jpg.rf.68dbdcbac5ee57cc4cac1ffacb3c3327.xml to 00061.xml
# Renamed: 00766_jpg.rf.19ee101cb7f981410eefbff7cafea991.jpg to 00062.jpg
# Renamed: 00766_jpg.rf.19ee101cb7f981410eefbff7cafea991.xml to 00062.xml
# Renamed: 00803_jpg.rf.440a0f863d8cc23d052624b76bcc0f1a.jpg to 00063.jpg
# Renamed: 00803_jpg.rf.440a0f863d8cc23d052624b76bcc0f1a.xml to 00063.xml
# Renamed: 00805_jpg.rf.58cb04526f0620808469cbaea3ac6bdd.jpg to 00064.jpg
# Renamed: 00805_jpg.rf.58cb04526f0620808469cbaea3ac6bdd.xml to 00064.xml
# Renamed: 00812_jpg.rf.ad779916d81f6d6a79a8bbe04191f0db.jpg to 00065.jpg
# Renamed: 00812_jpg.rf.ad779916d81f6d6a79a8bbe04191f0db.xml to 00065.xml
# Renamed: 00816_jpg.rf.335edc00b2dfbe40ec24a2b29f82b78c.jpg to 00066.jpg
# Renamed: 00816_jpg.rf.335edc00b2dfbe40ec24a2b29f82b78c.xml to 00066.xml
# Renamed: 00820_jpg.rf.547ea40c91249b40b354070140758965.jpg to 00067.jpg
# Renamed: 00820_jpg.rf.547ea40c91249b40b354070140758965.xml to 00067.xml
# Renamed: 00828_jpg.rf.1e87f5f4a4d0d21545e0e79a88dda596.jpg to 00068.jpg
# Renamed: 00828_jpg.rf.1e87f5f4a4d0d21545e0e79a88dda596.xml to 00068.xml
# Renamed: 00830_jpg.rf.9f4293b9d5282056ecd6f9ae01adb37b.jpg to 00069.jpg
# Renamed: 00830_jpg.rf.9f4293b9d5282056ecd6f9ae01adb37b.xml to 00069.xml
# Renamed: 00847_jpg.rf.cd411edb5a2e3d8132d1a5ffed096ea3.jpg to 00070.jpg
# Renamed: 00847_jpg.rf.cd411edb5a2e3d8132d1a5ffed096ea3.xml to 00070.xml
# Renamed: 00853_jpg.rf.e6d01b6aaaa80240441c31d07021a135.jpg to 00071.jpg
# Renamed: 00853_jpg.rf.e6d01b6aaaa80240441c31d07021a135.xml to 00071.xml
# Renamed: 00877_jpg.rf.1f8a9b3eb5b54e836d28a044692ac03b.jpg to 00072.jpg
# Renamed: 00877_jpg.rf.1f8a9b3eb5b54e836d28a044692ac03b.xml to 00072.xml
# Renamed: 00889_jpg.rf.01cb9f0fba28ac90e4178e8f49c3578a.jpg to 00073.jpg
# Renamed: 00889_jpg.rf.01cb9f0fba28ac90e4178e8f49c3578a.xml to 00073.xml
# Renamed: 00893_jpg.rf.0512d1e0bff90b3ab1b5c47276772a66.jpg to 00074.jpg
# Renamed: 00893_jpg.rf.0512d1e0bff90b3ab1b5c47276772a66.xml to 00074.xml
# Renamed: 00899_jpg.rf.bb19f617116ac8ca90ea9a69ddc4a9b5.jpg to 00075.jpg
# Renamed: 00899_jpg.rf.bb19f617116ac8ca90ea9a69ddc4a9b5.xml to 00075.xml
# Renamed: 00915_jpg.rf.ed713973994cbac918bb3c648c51df6a.jpg to 00076.jpg
# Renamed: 00915_jpg.rf.ed713973994cbac918bb3c648c51df6a.xml to 00076.xml
# Renamed: 00926_jpg.rf.c76a5ddc2d69f5370ce8eb1acf15a18d.jpg to 00077.jpg
# Renamed: 00926_jpg.rf.c76a5ddc2d69f5370ce8eb1acf15a18d.xml to 00077.xml
# Renamed: 00931_jpg.rf.5e6045978cfade503566e00c20d671b6.jpg to 00078.jpg
# Renamed: 00931_jpg.rf.5e6045978cfade503566e00c20d671b6.xml to 00078.xml
# Renamed: 00958_jpg.rf.7ecb027ce9495c4f40f9278404b07418.jpg to 00079.jpg
# Renamed: 00958_jpg.rf.7ecb027ce9495c4f40f9278404b07418.xml to 00079.xml
# Renamed: 00959_jpg.rf.1d65d381f6852d88f2a78522d0eff441.jpg to 00080.jpg
# Renamed: 00959_jpg.rf.1d65d381f6852d88f2a78522d0eff441.xml to 00080.xml
# Renamed: 00975_jpg.rf.6c0323d88cefe0836fddda95b339e7d2.jpg to 00081.jpg
# Renamed: 00975_jpg.rf.6c0323d88cefe0836fddda95b339e7d2.xml to 00081.xml
# Renamed: 00976_jpg.rf.7c902309658b11bd29b48fad9ad056f1.jpg to 00082.jpg
# Renamed: 00976_jpg.rf.7c902309658b11bd29b48fad9ad056f1.xml to 00082.xml
# Renamed: 00981_jpg.rf.ec698481e56e6f0c48a1d0315f6d9804.jpg to 00083.jpg
# Renamed: 00981_jpg.rf.ec698481e56e6f0c48a1d0315f6d9804.xml to 00083.xml
# Renamed: 00983_jpg.rf.f4f9f380b9e7c32fd8d99d0d690814a5.jpg to 00084.jpg
# Renamed: 00983_jpg.rf.f4f9f380b9e7c32fd8d99d0d690814a5.xml to 00084.xml
# Renamed: 00987_jpg.rf.76db84ef514f8b955c17d7836cb86750.jpg to 00085.jpg
# Renamed: 00987_jpg.rf.76db84ef514f8b955c17d7836cb86750.xml to 00085.xml
# Renamed: 00988_jpg.rf.6537415c90d407503781ca035d748dc0.jpg to 00086.jpg
# Renamed: 00988_jpg.rf.6537415c90d407503781ca035d748dc0.xml to 00086.xml
# Renamed: 00989_jpg.rf.346263e38f7f9a461d8ee23b35c93c49.jpg to 00087.jpg
# Renamed: 00989_jpg.rf.346263e38f7f9a461d8ee23b35c93c49.xml to 00087.xml
# Renamed: 01004_jpg.rf.dec88ae9d8517b6383af6145e14365d5.jpg to 00088.jpg
# Renamed: 01004_jpg.rf.dec88ae9d8517b6383af6145e14365d5.xml to 00088.xml
# Renamed: 01008_jpg.rf.b63923f18a7b16737a450c7602c2f0b8.jpg to 00089.jpg
# Renamed: 01008_jpg.rf.b63923f18a7b16737a450c7602c2f0b8.xml to 00089.xml
# Renamed: 01014_jpg.rf.621de994a1d809ee472a1dc2067a45d5.jpg to 00090.jpg
# Renamed: 01014_jpg.rf.621de994a1d809ee472a1dc2067a45d5.xml to 00090.xml
# Renamed: 01015_jpg.rf.73322cf3c3d9db09cd7142d0bc7776f7.jpg to 00091.jpg
# Renamed: 01015_jpg.rf.73322cf3c3d9db09cd7142d0bc7776f7.xml to 00091.xml
# Renamed: 01016_jpg.rf.ef3c4341aca75ac09bf2139e1372c10c.jpg to 00092.jpg
# Renamed: 01016_jpg.rf.ef3c4341aca75ac09bf2139e1372c10c.xml to 00092.xml
# Renamed: 01080_jpg.rf.ca548a72f77a3c4a11931ededecfeea5.jpg to 00093.jpg
# Renamed: 01080_jpg.rf.ca548a72f77a3c4a11931ededecfeea5.xml to 00093.xml
# Renamed: 01106_jpg.rf.99c732b8a5b2c925cefca8b58ea78bf8.jpg to 00094.jpg
# Renamed: 01106_jpg.rf.99c732b8a5b2c925cefca8b58ea78bf8.xml to 00094.xml
# Renamed: 01132_jpg.rf.0eb5b731401a4dbf6e926da68760263c.jpg to 00095.jpg
# Renamed: 01132_jpg.rf.0eb5b731401a4dbf6e926da68760263c.xml to 00095.xml
# Renamed: 01135_jpg.rf.ee5a1c6ec2dd82008f41624b056d7a76.jpg to 00096.jpg
# Renamed: 01135_jpg.rf.ee5a1c6ec2dd82008f41624b056d7a76.xml to 00096.xml
# Renamed: 01139_jpg.rf.c77f47e4c2d14e03b31880287a5aff05.jpg to 00097.jpg
# Renamed: 01139_jpg.rf.c77f47e4c2d14e03b31880287a5aff05.xml to 00097.xml
# Renamed: 01158_jpg.rf.18008b2722af58f81212c3578ee2eae9.jpg to 00098.jpg
# Renamed: 01158_jpg.rf.18008b2722af58f81212c3578ee2eae9.xml to 00098.xml
# Renamed: 01163_jpg.rf.fc965841c2fa4570d9b48b8d605098cc.jpg to 00099.jpg
# Renamed: 01163_jpg.rf.fc965841c2fa4570d9b48b8d605098cc.xml to 00099.xml
# Renamed: 01164_jpg.rf.90d5bfdd7aff1ce6b6f19adfa57e6b95.jpg to 00100.jpg
# Renamed: 01164_jpg.rf.90d5bfdd7aff1ce6b6f19adfa57e6b95.xml to 00100.xml
# Renamed: 01174_jpg.rf.6d96119f4a0d7732e0154059b00b5738.jpg to 00101.jpg
# Renamed: 01174_jpg.rf.6d96119f4a0d7732e0154059b00b5738.xml to 00101.xml
# Renamed: 01181_jpg.rf.1d5f69feafdbbd96f8d11a58374e7d81.jpg to 00102.jpg
# Renamed: 01181_jpg.rf.1d5f69feafdbbd96f8d11a58374e7d81.xml to 00102.xml
# Renamed: 01207_jpg.rf.761e5835fe2f27e1e6279bb68b8ba82b.jpg to 00103.jpg
# Renamed: 01207_jpg.rf.761e5835fe2f27e1e6279bb68b8ba82b.xml to 00103.xml
# Renamed: 01216_jpg.rf.fbc97d98ec31a5ea1595a97e98cc1644.jpg to 00104.jpg
# Renamed: 01216_jpg.rf.fbc97d98ec31a5ea1595a97e98cc1644.xml to 00104.xml
# Renamed: 01229_jpg.rf.2e419cb8603fe178ec8050fac0a4bebf.jpg to 00105.jpg
# Renamed: 01229_jpg.rf.2e419cb8603fe178ec8050fac0a4bebf.xml to 00105.xml
# Renamed: 01234_jpg.rf.93c7a9f5a70dc762127530491c74f2d7.jpg to 00106.jpg
# Renamed: 01234_jpg.rf.93c7a9f5a70dc762127530491c74f2d7.xml to 00106.xml
# Renamed: 01248_jpg.rf.bc15c5944433311876961266ac20bb44.jpg to 00107.jpg
# Renamed: 01248_jpg.rf.bc15c5944433311876961266ac20bb44.xml to 00107.xml
# Renamed: 01250_jpg.rf.136580d8a869849e0ee4e06aaf85844f.jpg to 00108.jpg
# Renamed: 01250_jpg.rf.136580d8a869849e0ee4e06aaf85844f.xml to 00108.xml
# Renamed: 01269_jpg.rf.edcf3174a2db2c28260d274ba21d32c8.jpg to 00109.jpg
# Renamed: 01269_jpg.rf.edcf3174a2db2c28260d274ba21d32c8.xml to 00109.xml
# Renamed: 01274_jpg.rf.914d55aae6077155f6f7a501e5541d14.jpg to 00110.jpg
# Renamed: 01274_jpg.rf.914d55aae6077155f6f7a501e5541d14.xml to 00110.xml
# Renamed: 01279_jpg.rf.e6a13a93b4e6fd82f24c86f88bd40317.jpg to 00111.jpg
# Renamed: 01279_jpg.rf.e6a13a93b4e6fd82f24c86f88bd40317.xml to 00111.xml
# Renamed: 01286_jpg.rf.404b31cd4b0bd9c0430a4f1df1a5d2df.jpg to 00112.jpg
# Renamed: 01286_jpg.rf.404b31cd4b0bd9c0430a4f1df1a5d2df.xml to 00112.xml
# Renamed: 01290_jpg.rf.ae98c37cb8305038028554417f38ca1a.jpg to 00113.jpg
# Renamed: 01290_jpg.rf.ae98c37cb8305038028554417f38ca1a.xml to 00113.xml
# Renamed: 01297_jpg.rf.f659831e18e5149bcf8204d4684ba3ae.jpg to 00114.jpg
# Renamed: 01297_jpg.rf.f659831e18e5149bcf8204d4684ba3ae.xml to 00114.xml
# Renamed: 01298_jpg.rf.d493f0aae380de4630da131c99f68dae.jpg to 00115.jpg
# Renamed: 01298_jpg.rf.d493f0aae380de4630da131c99f68dae.xml to 00115.xml
# Renamed: 01310_jpg.rf.88d64d133a2f5ade439437385de2dcb5.jpg to 00116.jpg
# Renamed: 01310_jpg.rf.88d64d133a2f5ade439437385de2dcb5.xml to 00116.xml
# Renamed: 01319_jpg.rf.ec61413f91c803737ab417670613f5de.jpg to 00117.jpg
# Renamed: 01319_jpg.rf.ec61413f91c803737ab417670613f5de.xml to 00117.xml
# Renamed: 01327_jpg.rf.5c3c95fd0642c8380969beca6213f79f.jpg to 00118.jpg
# Renamed: 01327_jpg.rf.5c3c95fd0642c8380969beca6213f79f.xml to 00118.xml
# Renamed: 01330_jpg.rf.97dd5336ff3468b8569c0bd9005187b4.jpg to 00119.jpg
# Renamed: 01330_jpg.rf.97dd5336ff3468b8569c0bd9005187b4.xml to 00119.xml
# Renamed: 01381_jpg.rf.baa85ecd51d0971d364d840ec6c54c5c.jpg to 00120.jpg
# Renamed: 01381_jpg.rf.baa85ecd51d0971d364d840ec6c54c5c.xml to 00120.xml
# Renamed: 01403_jpg.rf.2ce33c74bd01b99bd483c1676f280525.jpg to 00121.jpg
# Renamed: 01403_jpg.rf.2ce33c74bd01b99bd483c1676f280525.xml to 00121.xml
# Renamed: 01418_jpg.rf.4c6f6454e238929d7b3073cc00cb1518.jpg to 00122.jpg
# Renamed: 01418_jpg.rf.4c6f6454e238929d7b3073cc00cb1518.xml to 00122.xml
# Renamed: 01441_jpg.rf.0943132e1d5c31f33285a6569407a0b1.jpg to 00123.jpg
# Renamed: 01441_jpg.rf.0943132e1d5c31f33285a6569407a0b1.xml to 00123.xml
# Renamed: 01452_jpg.rf.7883b9172a7b8d60e135f46d03ebbdda.jpg to 00124.jpg
# Renamed: 01452_jpg.rf.7883b9172a7b8d60e135f46d03ebbdda.xml to 00124.xml
# Renamed: 01483_jpg.rf.17acb63965db4c33dfb875738186d712.jpg to 00125.jpg
# Renamed: 01483_jpg.rf.17acb63965db4c33dfb875738186d712.xml to 00125.xml
# Renamed: 01486_jpg.rf.d5192b0b93528dcae1592b612757c48c.jpg to 00126.jpg
# Renamed: 01486_jpg.rf.d5192b0b93528dcae1592b612757c48c.xml to 00126.xml
# Renamed: 01489_jpg.rf.1189c50a9c175b35cc0fa9ed340266cb.jpg to 00127.jpg
# Renamed: 01489_jpg.rf.1189c50a9c175b35cc0fa9ed340266cb.xml to 00127.xml
# Renamed: 01492_jpg.rf.a7e7ab3ca8cdb326783148f53047993b.jpg to 00128.jpg
# Renamed: 01492_jpg.rf.a7e7ab3ca8cdb326783148f53047993b.xml to 00128.xml
# Renamed: 01516_jpg.rf.c5be72f4a1bd39b399b85b31a0a94550.jpg to 00129.jpg
# Renamed: 01516_jpg.rf.c5be72f4a1bd39b399b85b31a0a94550.xml to 00129.xml
# Renamed: 01530_jpg.rf.f18620464161d37b3d86d6337f929b2c.jpg to 00130.jpg
# Renamed: 01530_jpg.rf.f18620464161d37b3d86d6337f929b2c.xml to 00130.xml
# Renamed: 01531_jpg.rf.aa423158e71cc49d7b147c827f0276c0.jpg to 00131.jpg
# Renamed: 01531_jpg.rf.aa423158e71cc49d7b147c827f0276c0.xml to 00131.xml
# Renamed: 01536_jpg.rf.a2222070263a101415186f333135ec8d.jpg to 00132.jpg
# Renamed: 01536_jpg.rf.a2222070263a101415186f333135ec8d.xml to 00132.xml
# Renamed: 01537_jpg.rf.709acd66e185806f6c507c68cebaa804.jpg to 00133.jpg
# Renamed: 01537_jpg.rf.709acd66e185806f6c507c68cebaa804.xml to 00133.xml
# Renamed: 01551_jpg.rf.46102d0986e92524cf630c93e4a4acb1.jpg to 00134.jpg
# Renamed: 01551_jpg.rf.46102d0986e92524cf630c93e4a4acb1.xml to 00134.xml
# Renamed: 01596_jpg.rf.15f1fd7abba9ef238a35c29f055bf875.jpg to 00135.jpg
# Renamed: 01596_jpg.rf.15f1fd7abba9ef238a35c29f055bf875.xml to 00135.xml
# Renamed: 01610_jpg.rf.8c19b42353207f47bf689319d810abd8.jpg to 00136.jpg
# Renamed: 01610_jpg.rf.8c19b42353207f47bf689319d810abd8.xml to 00136.xml
# Renamed: 01612_jpg.rf.67a934a504938da2e9ba686a2311c799.jpg to 00137.jpg
# Renamed: 01612_jpg.rf.67a934a504938da2e9ba686a2311c799.xml to 00137.xml
# Renamed: 01616_jpg.rf.64ee00e6c0d9c9812baf1f0c0957c7e5.jpg to 00138.jpg
# Renamed: 01616_jpg.rf.64ee00e6c0d9c9812baf1f0c0957c7e5.xml to 00138.xml
# Renamed: 01636_jpg.rf.70dedbb847759878162be68da04ef52c.jpg to 00139.jpg
# Renamed: 01636_jpg.rf.70dedbb847759878162be68da04ef52c.xml to 00139.xml
# Renamed: 01643_jpg.rf.a16ba1f814147e6aa34bda7cbf1a648d.jpg to 00140.jpg
# Renamed: 01643_jpg.rf.a16ba1f814147e6aa34bda7cbf1a648d.xml to 00140.xml
# Renamed: 01648_jpg.rf.44bf5165bac2960262b347a668cf4c76.jpg to 00141.jpg
# Renamed: 01648_jpg.rf.44bf5165bac2960262b347a668cf4c76.xml to 00141.xml
# Renamed: 01677_jpg.rf.6b75753be9b742c965e7dc2342ff30a6.jpg to 00142.jpg
# Renamed: 01677_jpg.rf.6b75753be9b742c965e7dc2342ff30a6.xml to 00142.xml
# Renamed: 01688_jpg.rf.00ae96864edfd3d35a955a4416149008.jpg to 00143.jpg
# Renamed: 01688_jpg.rf.00ae96864edfd3d35a955a4416149008.xml to 00143.xml
# Renamed: 01696_jpg.rf.38b39f99c91f6f25d0f4427358eba970.jpg to 00144.jpg
# Renamed: 01696_jpg.rf.38b39f99c91f6f25d0f4427358eba970.xml to 00144.xml
# Renamed: 01700_jpg.rf.9ce22951578285d8196cbdc64f7353c6.jpg to 00145.jpg
# Renamed: 01700_jpg.rf.9ce22951578285d8196cbdc64f7353c6.xml to 00145.xml
# Renamed: 01702_jpg.rf.e4b8fc840bd465e64c1f3f4506ffc3fe.jpg to 00146.jpg
# Renamed: 01702_jpg.rf.e4b8fc840bd465e64c1f3f4506ffc3fe.xml to 00146.xml
# Renamed: 01703_jpg.rf.198bbdffa5db3f3bc2a71ae83bb33d58.jpg to 00147.jpg
# Renamed: 01703_jpg.rf.198bbdffa5db3f3bc2a71ae83bb33d58.xml to 00147.xml
# Renamed: 01707_jpg.rf.84e5bdd17f4947e7d442c80edaeeb51e.jpg to 00148.jpg
# Renamed: 01707_jpg.rf.84e5bdd17f4947e7d442c80edaeeb51e.xml to 00148.xml
# Renamed: 01728_jpg.rf.88aec1c87f5a072b2c0ae3d757084962.jpg to 00149.jpg
# Renamed: 01728_jpg.rf.88aec1c87f5a072b2c0ae3d757084962.xml to 00149.xml
# Renamed: 01730_jpg.rf.2dba00872b4e4b70d447326746874e13.jpg to 00150.jpg
# Renamed: 01730_jpg.rf.2dba00872b4e4b70d447326746874e13.xml to 00150.xml
# Renamed: 01733_jpg.rf.f6b3ffd7494c8c31ce78dcdd2dd94149.jpg to 00151.jpg
# Renamed: 01733_jpg.rf.f6b3ffd7494c8c31ce78dcdd2dd94149.xml to 00151.xml
# Renamed: 01758_jpg.rf.13186d33960aac710e9d06bb06385ee0.jpg to 00152.jpg
# Renamed: 01758_jpg.rf.13186d33960aac710e9d06bb06385ee0.xml to 00152.xml
# Renamed: 01760_jpg.rf.d81be719c1423a9b7749410d019eb6b4.jpg to 00153.jpg
# Renamed: 01760_jpg.rf.d81be719c1423a9b7749410d019eb6b4.xml to 00153.xml
# Renamed: 01764_jpg.rf.42f987ad35d59e6d85de3541d55f7af2.jpg to 00154.jpg
# Renamed: 01764_jpg.rf.42f987ad35d59e6d85de3541d55f7af2.xml to 00154.xml
# Renamed: 01770_jpg.rf.68719318aaf11c6f372f063b9c4dbf6b.jpg to 00155.jpg
# Renamed: 01770_jpg.rf.68719318aaf11c6f372f063b9c4dbf6b.xml to 00155.xml
# Renamed: 01780_jpg.rf.84b6d296214bc73aa58d2d3406f415d5.jpg to 00156.jpg
# Renamed: 01780_jpg.rf.84b6d296214bc73aa58d2d3406f415d5.xml to 00156.xml
# Renamed: 01786_jpg.rf.6bf6cabcd0016ba95ab4fd22b1fe19ae.jpg to 00157.jpg
# Renamed: 01786_jpg.rf.6bf6cabcd0016ba95ab4fd22b1fe19ae.xml to 00157.xml
# Renamed: 01788_jpg.rf.bb828e80d1636285b3f0a05f1b58fb7a.jpg to 00158.jpg
# Renamed: 01788_jpg.rf.bb828e80d1636285b3f0a05f1b58fb7a.xml to 00158.xml
# Renamed: 01794_jpg.rf.64423084bd106984c5bfe810cb27b171.jpg to 00159.jpg
# Renamed: 01794_jpg.rf.64423084bd106984c5bfe810cb27b171.xml to 00159.xml
# Renamed: 01797_jpg.rf.ad0c981d95bc0f05d17d188b875f9d0e.jpg to 00160.jpg
# Renamed: 01797_jpg.rf.ad0c981d95bc0f05d17d188b875f9d0e.xml to 00160.xml
# Renamed: 01823_jpg.rf.16e02c16d650a7cbffcab27ececc7697.jpg to 00161.jpg
# Renamed: 01823_jpg.rf.16e02c16d650a7cbffcab27ececc7697.xml to 00161.xml
# Renamed: 01866_jpg.rf.7c79a6e554dda385a1664d7a929fec1b.jpg to 00162.jpg
# Renamed: 01866_jpg.rf.7c79a6e554dda385a1664d7a929fec1b.xml to 00162.xml
# Renamed: 01896_jpg.rf.d03a70d41dbddd6509ca70ccbacdfecb.jpg to 00163.jpg
# Renamed: 01896_jpg.rf.d03a70d41dbddd6509ca70ccbacdfecb.xml to 00163.xml
# Renamed: 01900_jpg.rf.c3149f40dac4a439d7293022cf13ae11.jpg to 00164.jpg
# Renamed: 01900_jpg.rf.c3149f40dac4a439d7293022cf13ae11.xml to 00164.xml
# Renamed: 01902_jpg.rf.d5bbd51cb7c7bee8cfe5b25c179e1b14.jpg to 00165.jpg
# Renamed: 01902_jpg.rf.d5bbd51cb7c7bee8cfe5b25c179e1b14.xml to 00165.xml
# Renamed: 01905_jpg.rf.5c25518d9fa6d27a4a2e6d482265a2ab.jpg to 00166.jpg
# Renamed: 01905_jpg.rf.5c25518d9fa6d27a4a2e6d482265a2ab.xml to 00166.xml
# Renamed: 01950_jpg.rf.275c31a7dfd81166acf477ff8e652ff0.jpg to 00167.jpg
# Renamed: 01950_jpg.rf.275c31a7dfd81166acf477ff8e652ff0.xml to 00167.xml
# Renamed: 01968_jpg.rf.b21770d921d7b5eb7e55bf845aff1d3c.jpg to 00168.jpg
# Renamed: 01968_jpg.rf.b21770d921d7b5eb7e55bf845aff1d3c.xml to 00168.xml
# Renamed: 01970_jpg.rf.88a50e04ec0389451882ad20f2c3e034.jpg to 00169.jpg
# Renamed: 01970_jpg.rf.88a50e04ec0389451882ad20f2c3e034.xml to 00169.xml
# Renamed: 01973_jpg.rf.b6473f3cf91cf376d025afff1cdf905f.jpg to 00170.jpg
# Renamed: 01973_jpg.rf.b6473f3cf91cf376d025afff1cdf905f.xml to 00170.xml
# Renamed: 01987_jpg.rf.4510e8784caa19de88dd41637555bb40.jpg to 00171.jpg
# Renamed: 01987_jpg.rf.4510e8784caa19de88dd41637555bb40.xml to 00171.xml
# Renamed: 01992_jpg.rf.47034ea9d3c3e27a32748f2deb95e02c.jpg to 00172.jpg
# Renamed: 01992_jpg.rf.47034ea9d3c3e27a32748f2deb95e02c.xml to 00172.xml
# Renamed: 01993_jpg.rf.4e25d5bab65131b0bf2e50304a351117.jpg to 00173.jpg
# Renamed: 01993_jpg.rf.4e25d5bab65131b0bf2e50304a351117.xml to 00173.xml
# Renamed: 02016_jpg.rf.079081a97f2a1ea1ea02758ac73ac8e8.jpg to 00174.jpg
# Renamed: 02016_jpg.rf.079081a97f2a1ea1ea02758ac73ac8e8.xml to 00174.xml
# Renamed: 02048_jpg.rf.08ef0e94ef145a2e3f297b51b211cc54.jpg to 00175.jpg
# Renamed: 02048_jpg.rf.08ef0e94ef145a2e3f297b51b211cc54.xml to 00175.xml
# Renamed: 02054_jpg.rf.b2607d3b11db54ce9d450f7f9e9b7f01.jpg to 00176.jpg
# Renamed: 02054_jpg.rf.b2607d3b11db54ce9d450f7f9e9b7f01.xml to 00176.xml
# Renamed: 02071_jpg.rf.58066b94b9ed9c88652394131094e0f1.jpg to 00177.jpg
# Renamed: 02071_jpg.rf.58066b94b9ed9c88652394131094e0f1.xml to 00177.xml
# Renamed: 02078_jpg.rf.4f17e86cae4efb0e89011788e7098d97.jpg to 00178.jpg
# Renamed: 02078_jpg.rf.4f17e86cae4efb0e89011788e7098d97.xml to 00178.xml
# Renamed: 02081_jpg.rf.831a7b5e5f6fb6525c044c99fce61bf1.jpg to 00179.jpg
# Renamed: 02081_jpg.rf.831a7b5e5f6fb6525c044c99fce61bf1.xml to 00179.xml
# Renamed: 02087_jpg.rf.3f8e9e2a35cde4415ff4a6c6441527dd.jpg to 00180.jpg
# Renamed: 02087_jpg.rf.3f8e9e2a35cde4415ff4a6c6441527dd.xml to 00180.xml
# Renamed: 02094_jpg.rf.972afd0bfee083fa3e762803acb0984d.jpg to 00181.jpg
# Renamed: 02094_jpg.rf.972afd0bfee083fa3e762803acb0984d.xml to 00181.xml
# Renamed: 02099_jpg.rf.b263aea03cbcd0893ef7810c86baa68d.jpg to 00182.jpg
# Renamed: 02099_jpg.rf.b263aea03cbcd0893ef7810c86baa68d.xml to 00182.xml
# Renamed: 02116_jpg.rf.4819391ed4129c88bbaa1a24b63dd9ae.jpg to 00183.jpg
# Renamed: 02116_jpg.rf.4819391ed4129c88bbaa1a24b63dd9ae.xml to 00183.xml
# Renamed: 02121_jpg.rf.13565da03a8236c646435193a1461f60.jpg to 00184.jpg
# Renamed: 02121_jpg.rf.13565da03a8236c646435193a1461f60.xml to 00184.xml
# Renamed: 02159_jpg.rf.fa41eb311ac384bf20da080bae7aa1dc.jpg to 00185.jpg
# Renamed: 02159_jpg.rf.fa41eb311ac384bf20da080bae7aa1dc.xml to 00185.xml
# Renamed: 02161_jpg.rf.3a285d96cfc7c87a0312d63fcb482335.jpg to 00186.jpg
# Renamed: 02161_jpg.rf.3a285d96cfc7c87a0312d63fcb482335.xml to 00186.xml
# Renamed: 02162_jpg.rf.5cae1df3d9f0af2c2af14d063dc00474.jpg to 00187.jpg
# Renamed: 02162_jpg.rf.5cae1df3d9f0af2c2af14d063dc00474.xml to 00187.xml
# Renamed: 02169_jpg.rf.880462dc4b115992b780226a8abe3077.jpg to 00188.jpg
# Renamed: 02169_jpg.rf.880462dc4b115992b780226a8abe3077.xml to 00188.xml
# Renamed: 02180_jpg.rf.d8fafd5a63b82afb13d21df414d6eeb8.jpg to 00189.jpg
# Renamed: 02180_jpg.rf.d8fafd5a63b82afb13d21df414d6eeb8.xml to 00189.xml
# Renamed: 02230_jpg.rf.248103538db1903d3b9a42da08e39dfb.jpg to 00190.jpg
# Renamed: 02230_jpg.rf.248103538db1903d3b9a42da08e39dfb.xml to 00190.xml
# Renamed: 02241_jpg.rf.87ce50e56802ce4f9b63b09b3c208a1f.jpg to 00191.jpg
# Renamed: 02241_jpg.rf.87ce50e56802ce4f9b63b09b3c208a1f.xml to 00191.xml
# Renamed: 02251_jpg.rf.8dc297976db3328192119a21919b3730.jpg to 00192.jpg
# Renamed: 02251_jpg.rf.8dc297976db3328192119a21919b3730.xml to 00192.xml
# Renamed: 02257_jpg.rf.d406dc0f504e5053fa0f3cccc6178c58.jpg to 00193.jpg
# Renamed: 02257_jpg.rf.d406dc0f504e5053fa0f3cccc6178c58.xml to 00193.xml
# Renamed: 02272_jpg.rf.fdbe1413be3aab083f30d6c5012d038d.jpg to 00194.jpg
# Renamed: 02272_jpg.rf.fdbe1413be3aab083f30d6c5012d038d.xml to 00194.xml
# Renamed: 02278_jpg.rf.f9f42b3864496595e59257730cbdb390.jpg to 00195.jpg
# Renamed: 02278_jpg.rf.f9f42b3864496595e59257730cbdb390.xml to 00195.xml
# Renamed: 02286_jpg.rf.d33ebe16417bf53bb4456afff99314bb.jpg to 00196.jpg
# Renamed: 02286_jpg.rf.d33ebe16417bf53bb4456afff99314bb.xml to 00196.xml
# Renamed: 02290_jpg.rf.58bcb56d77a693af8e2d79c1461759a0.jpg to 00197.jpg
# Renamed: 02290_jpg.rf.58bcb56d77a693af8e2d79c1461759a0.xml to 00197.xml
# Renamed: 02296_jpg.rf.7cfcd6312cfaf99965e0510bf45c4dc7.jpg to 00198.jpg
# Renamed: 02296_jpg.rf.7cfcd6312cfaf99965e0510bf45c4dc7.xml to 00198.xml
# Renamed: 02301_jpg.rf.6a0aaf03d240f511edcc6839494930be.jpg to 00199.jpg
# Renamed: 02301_jpg.rf.6a0aaf03d240f511edcc6839494930be.xml to 00199.xml
# Renamed: 02338_jpg.rf.d187d261c30a22fea28ac3ae1fa4320c.jpg to 00200.jpg
# Renamed: 02338_jpg.rf.d187d261c30a22fea28ac3ae1fa4320c.xml to 00200.xml
# Renamed: 02357_jpg.rf.0a2c980796c1d8809eb13acd22313a56.jpg to 00201.jpg
# Renamed: 02357_jpg.rf.0a2c980796c1d8809eb13acd22313a56.xml to 00201.xml
# Renamed: 02361_jpg.rf.ea94a9660353a1fab6e8d9208eac5141.jpg to 00202.jpg
# Renamed: 02361_jpg.rf.ea94a9660353a1fab6e8d9208eac5141.xml to 00202.xml
# Renamed: 02395_jpg.rf.0dafb68b5a141aa1d74ceb5b0f8464bf.jpg to 00203.jpg
# Renamed: 02395_jpg.rf.0dafb68b5a141aa1d74ceb5b0f8464bf.xml to 00203.xml
# Renamed: 02398_jpg.rf.be61780c3fc2085b9e101d84de18b51e.jpg to 00204.jpg
# Renamed: 02398_jpg.rf.be61780c3fc2085b9e101d84de18b51e.xml to 00204.xml
# Renamed: 02401_jpg.rf.4cd172a0b35ae7cba3c4bf319c26d5a2.jpg to 00205.jpg
# Renamed: 02401_jpg.rf.4cd172a0b35ae7cba3c4bf319c26d5a2.xml to 00205.xml
# Renamed: 02402_jpg.rf.1c16dd5e176999329593cba25d3eb8e8.jpg to 00206.jpg
# Renamed: 02402_jpg.rf.1c16dd5e176999329593cba25d3eb8e8.xml to 00206.xml
# Renamed: 02434_jpg.rf.e04cd133bc2b9286f9695018800c96f8.jpg to 00207.jpg
# Renamed: 02434_jpg.rf.e04cd133bc2b9286f9695018800c96f8.xml to 00207.xml
# Renamed: 02439_jpg.rf.09f1acdd5243bf3600539b66da00f2fb.jpg to 00208.jpg
# Renamed: 02439_jpg.rf.09f1acdd5243bf3600539b66da00f2fb.xml to 00208.xml
# Renamed: 02458_jpg.rf.cba86a4e3ea592c697bc91c67282c05c.jpg to 00209.jpg
# Renamed: 02458_jpg.rf.cba86a4e3ea592c697bc91c67282c05c.xml to 00209.xml
# Renamed: 02476_jpg.rf.4fece8bcde5e7cb6d06514f8bdd4e51a.jpg to 00210.jpg
# Renamed: 02476_jpg.rf.4fece8bcde5e7cb6d06514f8bdd4e51a.xml to 00210.xml
# Renamed: 02499_jpg.rf.2c978b2b61ab389f30a2878d58f97054.jpg to 00211.jpg
# Renamed: 02499_jpg.rf.2c978b2b61ab389f30a2878d58f97054.xml to 00211.xml
# Renamed: 02507_jpg.rf.e4b6f2e2b9b0f3c2dd616d082a188456.jpg to 00212.jpg
# Renamed: 02507_jpg.rf.e4b6f2e2b9b0f3c2dd616d082a188456.xml to 00212.xml
# Renamed: 02515_jpg.rf.5ca3f3b0772d9dcdbf8f2da6353e5596.jpg to 00213.jpg
# Renamed: 02515_jpg.rf.5ca3f3b0772d9dcdbf8f2da6353e5596.xml to 00213.xml
# Renamed: 02516_jpg.rf.8902519223979f0ea1a85b974a70de0b.jpg to 00214.jpg
# Renamed: 02516_jpg.rf.8902519223979f0ea1a85b974a70de0b.xml to 00214.xml
# Renamed: 02529_jpg.rf.13a94f8b3725f3bf006c69dd3d89d9f9.jpg to 00215.jpg
# Renamed: 02529_jpg.rf.13a94f8b3725f3bf006c69dd3d89d9f9.xml to 00215.xml
# Renamed: 02532_jpg.rf.4bb0d797c3488ce9e11604a59e109603.jpg to 00216.jpg
# Renamed: 02532_jpg.rf.4bb0d797c3488ce9e11604a59e109603.xml to 00216.xml
# Renamed: 02536_jpg.rf.cddd6f96020c0c5d5be977749723a8c1.jpg to 00217.jpg
# Renamed: 02536_jpg.rf.cddd6f96020c0c5d5be977749723a8c1.xml to 00217.xml
# Renamed: 02537_jpg.rf.b4f67bd3af7c7d44c3650c07ef338dfa.jpg to 00218.jpg
# Renamed: 02537_jpg.rf.b4f67bd3af7c7d44c3650c07ef338dfa.xml to 00218.xml
# Renamed: 02550_jpg.rf.c29148fdb2a7df9f8904597f4e76a47e.jpg to 00219.jpg
# Renamed: 02550_jpg.rf.c29148fdb2a7df9f8904597f4e76a47e.xml to 00219.xml
# Renamed: 02557_jpg.rf.9159fe0be8a3489ff8fba01c882e0579.jpg to 00220.jpg
# Renamed: 02557_jpg.rf.9159fe0be8a3489ff8fba01c882e0579.xml to 00220.xml
# Renamed: 02591_jpg.rf.574d71df723cf0823829469be70840a4.jpg to 00221.jpg
# Renamed: 02591_jpg.rf.574d71df723cf0823829469be70840a4.xml to 00221.xml
# Renamed: 02606_jpg.rf.342c79aa6b9c1464c468c2d3871ed6b5.jpg to 00222.jpg
# Renamed: 02606_jpg.rf.342c79aa6b9c1464c468c2d3871ed6b5.xml to 00222.xml
# Renamed: 02620_jpg.rf.5ed1fc367418053d5867cdca2e4eb59c.jpg to 00223.jpg
# Renamed: 02620_jpg.rf.5ed1fc367418053d5867cdca2e4eb59c.xml to 00223.xml
# Renamed: 02648_jpg.rf.5c76706f2a92e0ec689ce1a4b2d5b922.jpg to 00224.jpg
# Renamed: 02648_jpg.rf.5c76706f2a92e0ec689ce1a4b2d5b922.xml to 00224.xml
# Renamed: 02661_jpg.rf.46056cc9e4290accd46fadf9dd986362.jpg to 00225.jpg
# Renamed: 02661_jpg.rf.46056cc9e4290accd46fadf9dd986362.xml to 00225.xml
# Renamed: 02662_jpg.rf.48538c80748c8baa7b7362c8dbbe3487.jpg to 00226.jpg
# Renamed: 02662_jpg.rf.48538c80748c8baa7b7362c8dbbe3487.xml to 00226.xml
# Renamed: 02670_jpg.rf.2490d479337474acb15298da7b72fc4d.jpg to 00227.jpg
# Renamed: 02670_jpg.rf.2490d479337474acb15298da7b72fc4d.xml to 00227.xml
# Renamed: 02701_jpg.rf.89529610aff13395b962f3ebdb8e5f77.jpg to 00228.jpg
# Renamed: 02701_jpg.rf.89529610aff13395b962f3ebdb8e5f77.xml to 00228.xml
# Renamed: 02718_jpg.rf.f4e80ccffe251b254211411672a6b934.jpg to 00229.jpg
# Renamed: 02718_jpg.rf.f4e80ccffe251b254211411672a6b934.xml to 00229.xml
# Renamed: 02725_jpg.rf.64d48cc6cf00e68432b38898c2e969b9.jpg to 00230.jpg
# Renamed: 02725_jpg.rf.64d48cc6cf00e68432b38898c2e969b9.xml to 00230.xml
# Renamed: 02738_jpg.rf.6ca839b9debc6b3caea7ac1f6573adbb.jpg to 00231.jpg
# Renamed: 02738_jpg.rf.6ca839b9debc6b3caea7ac1f6573adbb.xml to 00231.xml
# Renamed: 02755_jpg.rf.1091cca0c68ae2721b3468e8379181c3.jpg to 00232.jpg
# Renamed: 02755_jpg.rf.1091cca0c68ae2721b3468e8379181c3.xml to 00232.xml
# Renamed: 02760_jpg.rf.669cad4e549895c7f49405ba8e8791ed.jpg to 00233.jpg
# Renamed: 02760_jpg.rf.669cad4e549895c7f49405ba8e8791ed.xml to 00233.xml
# Renamed: 02791_jpg.rf.d01f693051f88e975e00be9e5e8913bc.jpg to 00234.jpg
# Renamed: 02791_jpg.rf.d01f693051f88e975e00be9e5e8913bc.xml to 00234.xml
# Renamed: 02799_jpg.rf.6d2ee1883285e94300eba4f7961be4af.jpg to 00235.jpg
# Renamed: 02799_jpg.rf.6d2ee1883285e94300eba4f7961be4af.xml to 00235.xml
# Renamed: 02803_jpg.rf.d3642af8ffdc83036a2adb635becbe67.jpg to 00236.jpg
# Renamed: 02803_jpg.rf.d3642af8ffdc83036a2adb635becbe67.xml to 00236.xml
# Renamed: 02804_jpg.rf.66f29e4739f3391c7eb23faa5a819b5a.jpg to 00237.jpg
# Renamed: 02804_jpg.rf.66f29e4739f3391c7eb23faa5a819b5a.xml to 00237.xml
# Renamed: 02817_jpg.rf.caa10acfc69dc62bdde21e1ca158633f.jpg to 00238.jpg
# Renamed: 02817_jpg.rf.caa10acfc69dc62bdde21e1ca158633f.xml to 00238.xml
# Renamed: 02820_jpg.rf.0b1a1adf021d1bdd672203e772f02712.jpg to 00239.jpg
# Renamed: 02820_jpg.rf.0b1a1adf021d1bdd672203e772f02712.xml to 00239.xml
# Renamed: 02826_jpg.rf.2f94a92f54ff1fafc4f3bc4af637331d.jpg to 00240.jpg
# Renamed: 02826_jpg.rf.2f94a92f54ff1fafc4f3bc4af637331d.xml to 00240.xml
# Renamed: 02830_jpg.rf.48e84c5a394ca3f8aed402e18cb42969.jpg to 00241.jpg
# Renamed: 02830_jpg.rf.48e84c5a394ca3f8aed402e18cb42969.xml to 00241.xml
# Renamed: 02840_jpg.rf.658722da2aa8f8c066f6ee73f603249f.jpg to 00242.jpg
# Renamed: 02840_jpg.rf.658722da2aa8f8c066f6ee73f603249f.xml to 00242.xml
# Renamed: 02845_jpg.rf.c3a179118dc7345ce7866b0e0e72e6fe.jpg to 00243.jpg
# Renamed: 02845_jpg.rf.c3a179118dc7345ce7866b0e0e72e6fe.xml to 00243.xml
# Renamed: 02849_jpg.rf.64477cacf4c374cfa0d90f5f28a9b244.jpg to 00244.jpg
# Renamed: 02849_jpg.rf.64477cacf4c374cfa0d90f5f28a9b244.xml to 00244.xml
# Renamed: 02859_jpg.rf.559d64184eca6d57eec689dd3862f142.jpg to 00245.jpg
# Renamed: 02859_jpg.rf.559d64184eca6d57eec689dd3862f142.xml to 00245.xml
# Renamed: 02871_jpg.rf.2f34c8d6341e20e3cafd6b1c7d200671.jpg to 00246.jpg
# Renamed: 02871_jpg.rf.2f34c8d6341e20e3cafd6b1c7d200671.xml to 00246.xml
# Renamed: 02873_jpg.rf.c8ad9e9d58faac8036be099dab5ee726.jpg to 00247.jpg
# Renamed: 02873_jpg.rf.c8ad9e9d58faac8036be099dab5ee726.xml to 00247.xml
# Renamed: 02894_jpg.rf.ad2401351063c2647a417d87c0eb5108.jpg to 00248.jpg
# Renamed: 02894_jpg.rf.ad2401351063c2647a417d87c0eb5108.xml to 00248.xml
# Renamed: 02904_jpg.rf.2fc8911e7ce8921455b55d1c37f6297d.jpg to 00249.jpg
# Renamed: 02904_jpg.rf.2fc8911e7ce8921455b55d1c37f6297d.xml to 00249.xml
# Renamed: 02907_jpg.rf.9d0459afd5dbdb2cbb997df696d21211.jpg to 00250.jpg
# Renamed: 02907_jpg.rf.9d0459afd5dbdb2cbb997df696d21211.xml to 00250.xml
# Renamed: 02915_jpg.rf.6e6a605d2c9d638404bf4f8cc5088681.jpg to 00251.jpg
# Renamed: 02915_jpg.rf.6e6a605d2c9d638404bf4f8cc5088681.xml to 00251.xml
# Renamed: 02916_jpg.rf.ce7ebd367816a770a0fbc31bc7c5937b.jpg to 00252.jpg
# Renamed: 02916_jpg.rf.ce7ebd367816a770a0fbc31bc7c5937b.xml to 00252.xml
# Renamed: 02932_jpg.rf.cf8516e62511a2f3c0eba4273f697a33.jpg to 00253.jpg
# Renamed: 02932_jpg.rf.cf8516e62511a2f3c0eba4273f697a33.xml to 00253.xml
# Renamed: 02944_jpg.rf.c8fcc4b263d451cab38a6b0fbb0d08ef.jpg to 00254.jpg
# Renamed: 02944_jpg.rf.c8fcc4b263d451cab38a6b0fbb0d08ef.xml to 00254.xml
# Renamed: 02957_jpg.rf.4573e4fea56789bc02fa8c9f2b18a900.jpg to 00255.jpg
# Renamed: 02957_jpg.rf.4573e4fea56789bc02fa8c9f2b18a900.xml to 00255.xml
# Renamed: 02959_jpg.rf.410f24655b7bd71b4328d4fb5923170e.jpg to 00256.jpg
# Renamed: 02959_jpg.rf.410f24655b7bd71b4328d4fb5923170e.xml to 00256.xml
# Renamed: 02963_jpg.rf.37c8b6bed799013e4ff2617afab92f79.jpg to 00257.jpg
# Renamed: 02963_jpg.rf.37c8b6bed799013e4ff2617afab92f79.xml to 00257.xml
# Renamed: 02964_jpg.rf.a8b8e5ed05fd2416334bdfde16517ee5.jpg to 00258.jpg
# Renamed: 02964_jpg.rf.a8b8e5ed05fd2416334bdfde16517ee5.xml to 00258.xml
# Renamed: 02972_jpg.rf.d60ee4ff09d5910ccbf7cc45b18d93dd.jpg to 00259.jpg
# Renamed: 02972_jpg.rf.d60ee4ff09d5910ccbf7cc45b18d93dd.xml to 00259.xml
# Renamed: 02974_jpg.rf.de6c2bf2702afa727bad094ed94d07fc.jpg to 00260.jpg
# Renamed: 02974_jpg.rf.de6c2bf2702afa727bad094ed94d07fc.xml to 00260.xml
# Renamed: 03000_jpg.rf.fc60ac61210800b615c9377bfa3bec35.jpg to 00261.jpg
# Renamed: 03000_jpg.rf.fc60ac61210800b615c9377bfa3bec35.xml to 00261.xml
# Renamed: 03014_jpg.rf.4e96ea8f247a624657678e8dfd8238ff.jpg to 00262.jpg
# Renamed: 03014_jpg.rf.4e96ea8f247a624657678e8dfd8238ff.xml to 00262.xml
# Renamed: 03019_jpg.rf.4a0ebd4675e2849f558fda87b39c1c6f.jpg to 00263.jpg
# Renamed: 03019_jpg.rf.4a0ebd4675e2849f558fda87b39c1c6f.xml to 00263.xml
# Renamed: 03025_jpg.rf.d70f21408b812acad678ebf16ac8913f.jpg to 00264.jpg
# Renamed: 03025_jpg.rf.d70f21408b812acad678ebf16ac8913f.xml to 00264.xml
# Renamed: 03028_jpg.rf.32b84a988daae7f9cfeda2131c048f47.jpg to 00265.jpg
# Renamed: 03028_jpg.rf.32b84a988daae7f9cfeda2131c048f47.xml to 00265.xml
# Renamed: 03030_jpg.rf.46894d4b4fb04a4f0f544aca432c262b.jpg to 00266.jpg
# Renamed: 03030_jpg.rf.46894d4b4fb04a4f0f544aca432c262b.xml to 00266.xml
# Renamed: 03031_jpg.rf.7aeda15ca08e1bfcc4a9de68a869ba71.jpg to 00267.jpg
# Renamed: 03031_jpg.rf.7aeda15ca08e1bfcc4a9de68a869ba71.xml to 00267.xml
# Renamed: 03041_jpg.rf.9acbf91cc57a8e121d6aec29775973ae.jpg to 00268.jpg
# Renamed: 03041_jpg.rf.9acbf91cc57a8e121d6aec29775973ae.xml to 00268.xml
# Renamed: 03044_jpg.rf.6e9d42451dfc5de796a00e51a28e230d.jpg to 00269.jpg
# Renamed: 03044_jpg.rf.6e9d42451dfc5de796a00e51a28e230d.xml to 00269.xml
# Renamed: 03051_jpg.rf.f622b656742e341e89010ac3dc76e762.jpg to 00270.jpg
# Renamed: 03051_jpg.rf.f622b656742e341e89010ac3dc76e762.xml to 00270.xml
# Renamed: 03060_jpg.rf.0757d076a646ad3b844ebee9d8944d6f.jpg to 00271.jpg
# Renamed: 03060_jpg.rf.0757d076a646ad3b844ebee9d8944d6f.xml to 00271.xml
# Renamed: 03092_jpg.rf.7cb1d0c104e4b789b3fc5265c40e452f.jpg to 00272.jpg
# Renamed: 03092_jpg.rf.7cb1d0c104e4b789b3fc5265c40e452f.xml to 00272.xml
# Renamed: 03108_jpg.rf.857723bfed8ce9c7e23f375fe58034ac.jpg to 00273.jpg
# Renamed: 03108_jpg.rf.857723bfed8ce9c7e23f375fe58034ac.xml to 00273.xml
# Renamed: 03109_jpg.rf.c7e51e4f9924b760d36ad98776d13cd4.jpg to 00274.jpg
# Renamed: 03109_jpg.rf.c7e51e4f9924b760d36ad98776d13cd4.xml to 00274.xml
# Renamed: 03110_jpg.rf.e9bda9e4babe2fc7ee11c0386d6f11f5.jpg to 00275.jpg
# Renamed: 03110_jpg.rf.e9bda9e4babe2fc7ee11c0386d6f11f5.xml to 00275.xml
# Renamed: 03119_jpg.rf.12e762583455784bf4e32fd4402644ce.jpg to 00276.jpg
# Renamed: 03119_jpg.rf.12e762583455784bf4e32fd4402644ce.xml to 00276.xml
# Renamed: 03121_jpg.rf.93ca5d2fbc0ad81c5f21f0b0492c1235.jpg to 00277.jpg
# Renamed: 03121_jpg.rf.93ca5d2fbc0ad81c5f21f0b0492c1235.xml to 00277.xml
# Renamed: 03123_jpg.rf.2183a7e702340d50b8d19b7996a61405.jpg to 00278.jpg
# Renamed: 03123_jpg.rf.2183a7e702340d50b8d19b7996a61405.xml to 00278.xml
# Renamed: 03139_jpg.rf.105697e54f31cd7535c7351ea09ea53b.jpg to 00279.jpg
# Renamed: 03139_jpg.rf.105697e54f31cd7535c7351ea09ea53b.xml to 00279.xml
# Renamed: 03141_jpg.rf.90aa45fbfd6c73175336157dad35c56a.jpg to 00280.jpg
# Renamed: 03141_jpg.rf.90aa45fbfd6c73175336157dad35c56a.xml to 00280.xml
# Renamed: 03147_jpg.rf.ef2f2360eb232e8ad71c4679c9981fb2.jpg to 00281.jpg
# Renamed: 03147_jpg.rf.ef2f2360eb232e8ad71c4679c9981fb2.xml to 00281.xml
# Renamed: 03152_jpg.rf.5c36b9b50a2673fe9029bf990c271d56.jpg to 00282.jpg
# Renamed: 03152_jpg.rf.5c36b9b50a2673fe9029bf990c271d56.xml to 00282.xml
# Renamed: 03157_jpg.rf.03c4e8b6663480408406f5753369f714.jpg to 00283.jpg
# Renamed: 03157_jpg.rf.03c4e8b6663480408406f5753369f714.xml to 00283.xml
# Renamed: 03158_jpg.rf.e201546e32b6057d572b6743537a44ed.jpg to 00284.jpg
# Renamed: 03158_jpg.rf.e201546e32b6057d572b6743537a44ed.xml to 00284.xml
# Renamed: 03163_jpg.rf.986688368c4eddf573e8abc505830f0b.jpg to 00285.jpg
# Renamed: 03163_jpg.rf.986688368c4eddf573e8abc505830f0b.xml to 00285.xml
# Renamed: 03166_jpg.rf.b7d2cd315138f7e70aa887e4708d3fed.jpg to 00286.jpg
# Renamed: 03166_jpg.rf.b7d2cd315138f7e70aa887e4708d3fed.xml to 00286.xml
# Renamed: 03171_jpg.rf.5771aa081d84538d8ce5caa69806feac.jpg to 00287.jpg
# Renamed: 03171_jpg.rf.5771aa081d84538d8ce5caa69806feac.xml to 00287.xml
# Renamed: 03189_jpg.rf.bb46e1b1f5dd22883862b4e5003bd458.jpg to 00288.jpg
# Renamed: 03189_jpg.rf.bb46e1b1f5dd22883862b4e5003bd458.xml to 00288.xml
# Renamed: 03206_jpg.rf.7855a57b9a255aecd883aa0e45e52633.jpg to 00289.jpg
# Renamed: 03206_jpg.rf.7855a57b9a255aecd883aa0e45e52633.xml to 00289.xml
# Renamed: 03212_jpg.rf.4e372a03aa9f6b4ff7e45e127adf43cd.jpg to 00290.jpg
# Renamed: 03212_jpg.rf.4e372a03aa9f6b4ff7e45e127adf43cd.xml to 00290.xml
# Renamed: 03218_jpg.rf.30ffa523fcaab33e4a1cf2f4b860831f.jpg to 00291.jpg
# Renamed: 03218_jpg.rf.30ffa523fcaab33e4a1cf2f4b860831f.xml to 00291.xml
# Renamed: 03225_jpg.rf.821bb44792483186a7f460c2492a80c9.jpg to 00292.jpg
# Renamed: 03225_jpg.rf.821bb44792483186a7f460c2492a80c9.xml to 00292.xml
# Renamed: 03248_jpg.rf.a2f5f02def64a540c9f3718a1a9a99c8.jpg to 00293.jpg
# Renamed: 03248_jpg.rf.a2f5f02def64a540c9f3718a1a9a99c8.xml to 00293.xml
# Renamed: 03278_jpg.rf.1c218ebc8a23e2c9ae425ef4e85e85f1.jpg to 00294.jpg
# Renamed: 03278_jpg.rf.1c218ebc8a23e2c9ae425ef4e85e85f1.xml to 00294.xml
# Renamed: 03279_jpg.rf.45f6236045dea68c837e878f3379077e.jpg to 00295.jpg
# Renamed: 03279_jpg.rf.45f6236045dea68c837e878f3379077e.xml to 00295.xml
# Renamed: 03291_jpg.rf.29004166d1fcf2331acd342c45347c00.jpg to 00296.jpg
# Renamed: 03291_jpg.rf.29004166d1fcf2331acd342c45347c00.xml to 00296.xml
# Renamed: 03317_jpg.rf.3d757e232dd5e4df2de4664484ef10d4.jpg to 00297.jpg
# Renamed: 03317_jpg.rf.3d757e232dd5e4df2de4664484ef10d4.xml to 00297.xml
# Renamed: 03324_jpg.rf.ebfcf65d150056b34fb38d22872f5d1a.jpg to 00298.jpg
# Renamed: 03324_jpg.rf.ebfcf65d150056b34fb38d22872f5d1a.xml to 00298.xml
# Renamed: 03332_jpg.rf.219e013f9cacdd04b4e6d9dae14e1995.jpg to 00299.jpg
# Renamed: 03332_jpg.rf.219e013f9cacdd04b4e6d9dae14e1995.xml to 00299.xml
# Renamed: 03341_jpg.rf.1df210f529a8ada04a2ed8753f232fff.jpg to 00300.jpg
# Renamed: 03341_jpg.rf.1df210f529a8ada04a2ed8753f232fff.xml to 00300.xml
# Renamed: 03347_jpg.rf.c5240300b017696e5f16059826591acd.jpg to 00301.jpg
# Renamed: 03347_jpg.rf.c5240300b017696e5f16059826591acd.xml to 00301.xml
# Renamed: 03355_jpg.rf.b32eab10b4af04731052a17359bec482.jpg to 00302.jpg
# Renamed: 03355_jpg.rf.b32eab10b4af04731052a17359bec482.xml to 00302.xml
# Renamed: 03358_jpg.rf.8b41d111e5c5b2ba3c1e658613dc1569.jpg to 00303.jpg
# Renamed: 03358_jpg.rf.8b41d111e5c5b2ba3c1e658613dc1569.xml to 00303.xml
# Renamed: 03367_jpg.rf.f00f183c365c77c05eb76bc5af2aed82.jpg to 00304.jpg
# Renamed: 03367_jpg.rf.f00f183c365c77c05eb76bc5af2aed82.xml to 00304.xml
# Renamed: 03383_jpg.rf.faabda45e5ee31b8024d4ac231e2df8b.jpg to 00305.jpg
# Renamed: 03383_jpg.rf.faabda45e5ee31b8024d4ac231e2df8b.xml to 00305.xml
# Renamed: 03384_jpg.rf.203777c7565dfcd136cb049a73400503.jpg to 00306.jpg
# Renamed: 03384_jpg.rf.203777c7565dfcd136cb049a73400503.xml to 00306.xml
# Renamed: 03386_jpg.rf.a274d92ea4fb9919dfeebaa76cd7fb84.jpg to 00307.jpg
# Renamed: 03386_jpg.rf.a274d92ea4fb9919dfeebaa76cd7fb84.xml to 00307.xml
# Renamed: 03387_jpg.rf.af7643690290a32c5287bfd5b5850f9e.jpg to 00308.jpg
# Renamed: 03387_jpg.rf.af7643690290a32c5287bfd5b5850f9e.xml to 00308.xml
# Renamed: 03395_jpg.rf.b78636f911afe9194ad2184738717801.jpg to 00309.jpg
# Renamed: 03395_jpg.rf.b78636f911afe9194ad2184738717801.xml to 00309.xml
# Renamed: 03407_jpg.rf.564bef8ecfb03e493b7f9ec2dd720f04.jpg to 00310.jpg
# Renamed: 03407_jpg.rf.564bef8ecfb03e493b7f9ec2dd720f04.xml to 00310.xml
# Renamed: 03416_jpg.rf.57ad6b114f17b5781f7b0d5b3f0c9918.jpg to 00311.jpg
# Renamed: 03416_jpg.rf.57ad6b114f17b5781f7b0d5b3f0c9918.xml to 00311.xml
# Renamed: 03423_jpg.rf.90a509cc517142430354b4bc09a9a9a5.jpg to 00312.jpg
# Renamed: 03423_jpg.rf.90a509cc517142430354b4bc09a9a9a5.xml to 00312.xml
# Renamed: 03428_jpg.rf.c3b61676396891baeb4b58613f61b2a2.jpg to 00313.jpg
# Renamed: 03428_jpg.rf.c3b61676396891baeb4b58613f61b2a2.xml to 00313.xml
# Renamed: 03433_jpg.rf.e1c5588bb3de673192d217cb2e3acb58.jpg to 00314.jpg
# Renamed: 03433_jpg.rf.e1c5588bb3de673192d217cb2e3acb58.xml to 00314.xml
# Renamed: 03449_jpg.rf.b91a742a3ec8f57fe5a5c3e2d169bd16.jpg to 00315.jpg
# Renamed: 03449_jpg.rf.b91a742a3ec8f57fe5a5c3e2d169bd16.xml to 00315.xml
# Renamed: 03453_jpg.rf.fcb70cb41563bb675803bda37f0f4d5a.jpg to 00316.jpg
# Renamed: 03453_jpg.rf.fcb70cb41563bb675803bda37f0f4d5a.xml to 00316.xml
# Renamed: 03455_jpg.rf.9b3d0e7eee23ad1a308088f01f93f2d3.jpg to 00317.jpg
# Renamed: 03455_jpg.rf.9b3d0e7eee23ad1a308088f01f93f2d3.xml to 00317.xml
# Renamed: 03457_jpg.rf.bbbf128f1ead144d2a2064abae40718e.jpg to 00318.jpg
# Renamed: 03457_jpg.rf.bbbf128f1ead144d2a2064abae40718e.xml to 00318.xml
# Renamed: 03475_jpg.rf.cba20c62720a685909069e97ac12b05b.jpg to 00319.jpg
# Renamed: 03475_jpg.rf.cba20c62720a685909069e97ac12b05b.xml to 00319.xml
# Renamed: 03476_jpg.rf.e854067cb7cb8107ccdb04569f67a521.jpg to 00320.jpg
# Renamed: 03476_jpg.rf.e854067cb7cb8107ccdb04569f67a521.xml to 00320.xml
# Renamed: 03485_jpg.rf.9d24cbbdf5a0ecb554b002b670a64665.jpg to 00321.jpg
# Renamed: 03485_jpg.rf.9d24cbbdf5a0ecb554b002b670a64665.xml to 00321.xml
# Renamed: 03486_jpg.rf.f7443c99795d0449258c70503e3fc231.jpg to 00322.jpg
# Renamed: 03486_jpg.rf.f7443c99795d0449258c70503e3fc231.xml to 00322.xml
# Renamed: 03487_jpg.rf.dca895644022e7802a1e88ba2eaa1304.jpg to 00323.jpg
# Renamed: 03487_jpg.rf.dca895644022e7802a1e88ba2eaa1304.xml to 00323.xml
# Renamed: 03494_jpg.rf.b012546a2bac3f145f261bff6fc963f7.jpg to 00324.jpg
# Renamed: 03494_jpg.rf.b012546a2bac3f145f261bff6fc963f7.xml to 00324.xml
# Renamed: 03528_jpg.rf.cd29ae378a8a3a8f9189c4c45e23fcd5.jpg to 00325.jpg
# Renamed: 03528_jpg.rf.cd29ae378a8a3a8f9189c4c45e23fcd5.xml to 00325.xml
# Renamed: 03533_jpg.rf.b43b303e59943f2cf507ee39745b70d9.jpg to 00326.jpg
# Renamed: 03533_jpg.rf.b43b303e59943f2cf507ee39745b70d9.xml to 00326.xml
# Renamed: 03535_jpg.rf.2457e7fe7ea3ca633e20c92f6f4faee4.jpg to 00327.jpg
# Renamed: 03535_jpg.rf.2457e7fe7ea3ca633e20c92f6f4faee4.xml to 00327.xml
# Renamed: 03540_jpg.rf.90d6f8729a5ffe931714fe5271e2bfba.jpg to 00328.jpg
# Renamed: 03540_jpg.rf.90d6f8729a5ffe931714fe5271e2bfba.xml to 00328.xml
# Renamed: 03541_jpg.rf.3386f1db05c72a6a3adf64812ec64ec1.jpg to 00329.jpg
# Renamed: 03541_jpg.rf.3386f1db05c72a6a3adf64812ec64ec1.xml to 00329.xml
# Renamed: 03545_jpg.rf.e4285477aab7e519382a721ac6b20ff3.jpg to 00330.jpg
# Renamed: 03545_jpg.rf.e4285477aab7e519382a721ac6b20ff3.xml to 00330.xml
# Renamed: 03567_jpg.rf.5c15198e0e0b195266a08112fdf14cb9.jpg to 00331.jpg
# Renamed: 03567_jpg.rf.5c15198e0e0b195266a08112fdf14cb9.xml to 00331.xml
# Renamed: 03568_jpg.rf.8f771e795c6482800dc9df559794904e.jpg to 00332.jpg
# Renamed: 03568_jpg.rf.8f771e795c6482800dc9df559794904e.xml to 00332.xml
# Renamed: 03575_jpg.rf.5f8a6ea325b1151d5c7798ef5f474e1e.jpg to 00333.jpg
# Renamed: 03575_jpg.rf.5f8a6ea325b1151d5c7798ef5f474e1e.xml to 00333.xml
# ...
# Renamed: 21912_jpg.rf.bede0da66a134e5fd63e0e187d4724b7.jpg to 02101.jpg
# Renamed: 21912_jpg.rf.bede0da66a134e5fd63e0e187d4724b7.xml to 02101.xml
# Renamed: 21942_jpg.rf.2fab767d9d3e9b406add1204332eef09.jpg to 02102.jpg
# Renamed: 21942_jpg.rf.2fab767d9d3e9b406add1204332eef09.xml to 02102.xml
# Renamed: 21953_jpg.rf.6b5595db08a4c1377b67603fd3566286.jpg to 02103.jpg
# Renamed: 21953_jpg.rf.6b5595db08a4c1377b67603fd3566286.xml to 02103.xml
# Renamed: 21956_jpg.rf.ce5a66567f774b7f5cc714591085b150.jpg to 02104.jpg
# Renamed: 21956_jpg.rf.ce5a66567f774b7f5cc714591085b150.xml to 02104.xml
# Renamed: 21960_jpg.rf.12597285ceaf700760b70120e3a9ffa9.jpg to 02105.jpg
# Renamed: 21960_jpg.rf.12597285ceaf700760b70120e3a9ffa9.xml to 02105.xml
# Renamed: 21965_jpg.rf.8d8203db3ba35ce5b3b9ddb25219d770.jpg to 02106.jpg
# Renamed: 21965_jpg.rf.8d8203db3ba35ce5b3b9ddb25219d770.xml to 02106.xml
# Renamed: 21970_jpg.rf.5d09f8b75298f3c8a2d813da1241bcc3.jpg to 02107.jpg
# Renamed: 21970_jpg.rf.5d09f8b75298f3c8a2d813da1241bcc3.xml to 02107.xml
# Renamed: 21971_jpg.rf.81037dc24ab1104263f84e15e32e8b09.jpg to 02108.jpg
# Renamed: 21971_jpg.rf.81037dc24ab1104263f84e15e32e8b09.xml to 02108.xml
# Renamed: 21983_jpg.rf.16e200a3cda320db5ff8d2ecaad2f8c5.jpg to 02109.jpg
# Renamed: 21983_jpg.rf.16e200a3cda320db5ff8d2ecaad2f8c5.xml to 02109.xml
# Renamed: 21984_jpg.rf.31d2f7af26a6a31e82a613f262743cc0.jpg to 02110.jpg
# Renamed: 21984_jpg.rf.31d2f7af26a6a31e82a613f262743cc0.xml to 02110.xml
# Renamed: 21986_jpg.rf.f8a3e36e88d300f7bb7d7625c5254d06.jpg to 02111.jpg
# Renamed: 21986_jpg.rf.f8a3e36e88d300f7bb7d7625c5254d06.xml to 02111.xml
# Renamed: 21989_jpg.rf.f6941ed10748af75591e815ebd1868f9.jpg to 02112.jpg
# Renamed: 21989_jpg.rf.f6941ed10748af75591e815ebd1868f9.xml to 02112.xml
# Renamed: 21990_jpg.rf.a104a9cb5ab57ffbdb34d55e79359812.jpg to 02113.jpg
# Renamed: 21990_jpg.rf.a104a9cb5ab57ffbdb34d55e79359812.xml to 02113.xml
# Renamed: 21993_jpg.rf.4870578e86708eb48c2fa06976d976c8.jpg to 02114.jpg
# Renamed: 21993_jpg.rf.4870578e86708eb48c2fa06976d976c8.xml to 02114.xml
# Renamed: 22016_jpg.rf.5a16996223fb1a7f9e189bbe33e58497.jpg to 02115.jpg
# Renamed: 22016_jpg.rf.5a16996223fb1a7f9e189bbe33e58497.xml to 02115.xml
# Renamed: 22063_jpg.rf.a44e02f580a289a406b0b8f2c8bd08f4.jpg to 02116.jpg
# Renamed: 22063_jpg.rf.a44e02f580a289a406b0b8f2c8bd08f4.xml to 02116.xml
# Renamed: 22088_jpg.rf.e3e25bcd5927fd323e3c6a555960155b.jpg to 02117.jpg
# Renamed: 22088_jpg.rf.e3e25bcd5927fd323e3c6a555960155b.xml to 02117.xml
# Renamed: 22092_jpg.rf.5aa9d108639b1693d6d28e4a2723ab2d.jpg to 02118.jpg
# Renamed: 22092_jpg.rf.5aa9d108639b1693d6d28e4a2723ab2d.xml to 02118.xml
# Renamed: 22096_jpg.rf.4175e66c8fd01fae0d7f0d684d2aa889.jpg to 02119.jpg
# Renamed: 22096_jpg.rf.4175e66c8fd01fae0d7f0d684d2aa889.xml to 02119.xml
# Renamed: 22099_jpg.rf.fd3dd496599274e33df00ac48c8932a8.jpg to 02120.jpg
# Renamed: 22099_jpg.rf.fd3dd496599274e33df00ac48c8932a8.xml to 02120.xml
# Renamed: 22119_jpg.rf.d1841dacbfb610b08d59d3e37a20e2fa.jpg to 02121.jpg
# Renamed: 22119_jpg.rf.d1841dacbfb610b08d59d3e37a20e2fa.xml to 02121.xml
# Renamed: 22123_jpg.rf.243125cab49d402df12443b03c70d690.jpg to 02122.jpg
# Renamed: 22123_jpg.rf.243125cab49d402df12443b03c70d690.xml to 02122.xml
# Renamed: 22127_jpg.rf.d1eafac5e9565744645944ea4edd937d.jpg to 02123.jpg
# Renamed: 22127_jpg.rf.d1eafac5e9565744645944ea4edd937d.xml to 02123.xml
# Renamed: 22128_jpg.rf.cdcfad21efb3e3e678f13e39dba06dcb.jpg to 02124.jpg
# Renamed: 22128_jpg.rf.cdcfad21efb3e3e678f13e39dba06dcb.xml to 02124.xml
# Renamed: 22134_jpg.rf.44cd313210f1bf4be2035448b0eed330.jpg to 02125.jpg
# Renamed: 22134_jpg.rf.44cd313210f1bf4be2035448b0eed330.xml to 02125.xml
# Renamed: 22141_jpg.rf.abfb63b6e700d8860b3c53d895cd0d6f.jpg to 02126.jpg
# Renamed: 22141_jpg.rf.abfb63b6e700d8860b3c53d895cd0d6f.xml to 02126.xml
# Renamed: 22180_jpg.rf.ab07e9003b170226cdce1b1726dde69a.jpg to 02127.jpg
# Renamed: 22180_jpg.rf.ab07e9003b170226cdce1b1726dde69a.xml to 02127.xml
# Renamed: 22193_jpg.rf.7c80449363c095f667af8b4244c42e92.jpg to 02128.jpg
# Renamed: 22193_jpg.rf.7c80449363c095f667af8b4244c42e92.xml to 02128.xml
# Renamed: 22195_jpg.rf.bd343196b798c1cf64a5b5ef5a1f461d.jpg to 02129.jpg
# Renamed: 22195_jpg.rf.bd343196b798c1cf64a5b5ef5a1f461d.xml to 02129.xml
# Renamed: 22198_jpg.rf.4bd411618353eff7717f8f93cb359b3c.jpg to 02130.jpg
# Renamed: 22198_jpg.rf.4bd411618353eff7717f8f93cb359b3c.xml to 02130.xml
# Renamed: 22208_jpg.rf.8a3e432a6fb19c49f5071c3ee3b328ea.jpg to 02131.jpg
# Renamed: 22208_jpg.rf.8a3e432a6fb19c49f5071c3ee3b328ea.xml to 02131.xml
# Renamed: 22219_jpg.rf.846834a94c24c499e9498c21cfb86b13.jpg to 02132.jpg
# Renamed: 22219_jpg.rf.846834a94c24c499e9498c21cfb86b13.xml to 02132.xml
# Renamed: 22224_jpg.rf.b08c977da64a4e22c00faa01058695c9.jpg to 02133.jpg
# Renamed: 22224_jpg.rf.b08c977da64a4e22c00faa01058695c9.xml to 02133.xml
# Renamed: 22227_jpg.rf.d4b634034ae5962b709c4670e0acb827.jpg to 02134.jpg
# Renamed: 22227_jpg.rf.d4b634034ae5962b709c4670e0acb827.xml to 02134.xml
# Renamed: 22228_jpg.rf.aabc966dbf3c331751a45cd801b12171.jpg to 02135.jpg
# Renamed: 22228_jpg.rf.aabc966dbf3c331751a45cd801b12171.xml to 02135.xml
# Renamed: 22301_jpg.rf.7941294711ad4acddbe8f1e525d43926.jpg to 02136.jpg
# Renamed: 22301_jpg.rf.7941294711ad4acddbe8f1e525d43926.xml to 02136.xml
# Renamed: 22318_jpg.rf.25eea8155268a5b59d3c8cb860ce6291.jpg to 02137.jpg
# Renamed: 22318_jpg.rf.25eea8155268a5b59d3c8cb860ce6291.xml to 02137.xml
# Renamed: 22336_jpg.rf.eb72bc3d71f1507f7c6ca7b9fd8fcab3.jpg to 02138.jpg
# Renamed: 22336_jpg.rf.eb72bc3d71f1507f7c6ca7b9fd8fcab3.xml to 02138.xml
# Renamed: 22341_jpg.rf.31f2e2f60353b2534b560547e76a45d6.jpg to 02139.jpg
# Renamed: 22341_jpg.rf.31f2e2f60353b2534b560547e76a45d6.xml to 02139.xml
# Renamed: 22347_jpg.rf.36eb4651f029830b696eb214a023b707.jpg to 02140.jpg
# Renamed: 22347_jpg.rf.36eb4651f029830b696eb214a023b707.xml to 02140.xml
# Renamed: 22352_jpg.rf.9a15762632265370331ddba781cd6cd5.jpg to 02141.jpg
# Renamed: 22352_jpg.rf.9a15762632265370331ddba781cd6cd5.xml to 02141.xml
# Renamed: 22358_jpg.rf.cfeaec9795457e182b228d87595f0fe9.jpg to 02142.jpg
# Renamed: 22358_jpg.rf.cfeaec9795457e182b228d87595f0fe9.xml to 02142.xml
# Renamed: 22364_jpg.rf.604c3da2d89aaf961a303cd5edbc6103.jpg to 02143.jpg
# Renamed: 22364_jpg.rf.604c3da2d89aaf961a303cd5edbc6103.xml to 02143.xml
# Renamed: 22369_jpg.rf.7e942257cf611da46e85195740fec64d.jpg to 02144.jpg
# Renamed: 22369_jpg.rf.7e942257cf611da46e85195740fec64d.xml to 02144.xml
# Renamed: 22380_jpg.rf.b66aef9d5decf384a443aa3c2349568f.jpg to 02145.jpg
# Renamed: 22380_jpg.rf.b66aef9d5decf384a443aa3c2349568f.xml to 02145.xml
# Renamed: 22382_jpg.rf.0bcec1a258659d39ff1511369ca0eb1b.jpg to 02146.jpg
# Renamed: 22382_jpg.rf.0bcec1a258659d39ff1511369ca0eb1b.xml to 02146.xml
# Renamed: 22395_jpg.rf.7c3e5f27494ac5a55b24e3c2e907b1a6.jpg to 02147.jpg
# Renamed: 22395_jpg.rf.7c3e5f27494ac5a55b24e3c2e907b1a6.xml to 02147.xml
# Renamed: 22424_jpg.rf.2966bfde6244ce9368e53b6b7e8c331a.jpg to 02148.jpg
# Renamed: 22424_jpg.rf.2966bfde6244ce9368e53b6b7e8c331a.xml to 02148.xml
# Renamed: 22426_jpg.rf.857a1a10427f880ed61c1b42b0329ae3.jpg to 02149.jpg
# Renamed: 22426_jpg.rf.857a1a10427f880ed61c1b42b0329ae3.xml to 02149.xml
# Renamed: 22434_jpg.rf.bdd7d61a8d4cc0a8394ac608fa694d4e.jpg to 02150.jpg
# Renamed: 22434_jpg.rf.bdd7d61a8d4cc0a8394ac608fa694d4e.xml to 02150.xml
# Renamed: 22438_jpg.rf.faa82ccafaec1a6dd5d96c5de74c7940.jpg to 02151.jpg
# Renamed: 22438_jpg.rf.faa82ccafaec1a6dd5d96c5de74c7940.xml to 02151.xml
# Renamed: 22477_jpg.rf.224e3ba4f3cc3d47f99e172a1bd0db24.jpg to 02152.jpg
# Renamed: 22477_jpg.rf.224e3ba4f3cc3d47f99e172a1bd0db24.xml to 02152.xml
# Renamed: 22481_jpg.rf.753b58f22a6d68877ef2eb460284c41b.jpg to 02153.jpg
# Renamed: 22481_jpg.rf.753b58f22a6d68877ef2eb460284c41b.xml to 02153.xml
# Renamed: 22500_jpg.rf.e719c5d8621f5a6cc64a074fe1276879.jpg to 02154.jpg
# Renamed: 22500_jpg.rf.e719c5d8621f5a6cc64a074fe1276879.xml to 02154.xml
# Renamed: 22502_jpg.rf.a1ce7ce3103dc2c223988e39a5d9b6de.jpg to 02155.jpg
# Renamed: 22502_jpg.rf.a1ce7ce3103dc2c223988e39a5d9b6de.xml to 02155.xml
# Renamed: 22512_jpg.rf.ebd1200e85dfd9bf6166d000cb33447d.jpg to 02156.jpg
# Renamed: 22512_jpg.rf.ebd1200e85dfd9bf6166d000cb33447d.xml to 02156.xml
# Renamed: 22542_jpg.rf.f04a97906d2747881b2f58a4483246d7.jpg to 02157.jpg
# Renamed: 22542_jpg.rf.f04a97906d2747881b2f58a4483246d7.xml to 02157.xml
# Renamed: 22557_jpg.rf.194e4cbc964004c7818bd0702962cf1a.jpg to 02158.jpg
# Renamed: 22557_jpg.rf.194e4cbc964004c7818bd0702962cf1a.xml to 02158.xml
# Renamed: 22558_jpg.rf.74770b645d7a8a778f34f7e85631e60a.jpg to 02159.jpg
# Renamed: 22558_jpg.rf.74770b645d7a8a778f34f7e85631e60a.xml to 02159.xml
# Renamed: 22560_jpg.rf.46811f0de719259c54e7838d8380b5e5.jpg to 02160.jpg
# Renamed: 22560_jpg.rf.46811f0de719259c54e7838d8380b5e5.xml to 02160.xml
# Renamed: 22580_jpg.rf.7858e77215f4442ea130657ca1c70d50.jpg to 02161.jpg
# Renamed: 22580_jpg.rf.7858e77215f4442ea130657ca1c70d50.xml to 02161.xml
# Renamed: 22581_jpg.rf.f5e4ffb21c18ac1834129bee7ad291e3.jpg to 02162.jpg
# Renamed: 22581_jpg.rf.f5e4ffb21c18ac1834129bee7ad291e3.xml to 02162.xml
# Renamed: 22585_jpg.rf.1fd1e9dbb7745635635d0e2dd3f0b56c.jpg to 02163.jpg
# Renamed: 22585_jpg.rf.1fd1e9dbb7745635635d0e2dd3f0b56c.xml to 02163.xml
# Renamed: 22608_jpg.rf.fe33f19d784958a03321d1e374be6035.jpg to 02164.jpg
# Renamed: 22608_jpg.rf.fe33f19d784958a03321d1e374be6035.xml to 02164.xml
# Renamed: 22617_jpg.rf.5894aee4b6d4ef8c8387f0912d421a91.jpg to 02165.jpg
# Renamed: 22617_jpg.rf.5894aee4b6d4ef8c8387f0912d421a91.xml to 02165.xml
# Renamed: 22619_jpg.rf.4875d6c03d15211d3c84622f225ce2cb.jpg to 02166.jpg
# Renamed: 22619_jpg.rf.4875d6c03d15211d3c84622f225ce2cb.xml to 02166.xml
# Renamed: 22629_jpg.rf.e0078f05d757e427a1d24bba74a2d369.jpg to 02167.jpg
# Renamed: 22629_jpg.rf.e0078f05d757e427a1d24bba74a2d369.xml to 02167.xml
# Renamed: 22630_jpg.rf.8f1c69b8254f1ccf38d0367391da19c3.jpg to 02168.jpg
# Renamed: 22630_jpg.rf.8f1c69b8254f1ccf38d0367391da19c3.xml to 02168.xml
# Renamed: 22638_jpg.rf.44aa954b1106d674596f9946ae02e359.jpg to 02169.jpg
# Renamed: 22638_jpg.rf.44aa954b1106d674596f9946ae02e359.xml to 02169.xml
# Renamed: 22643_jpg.rf.b2fce8d40b229d62fc25ba293def973b.jpg to 02170.jpg
# Renamed: 22643_jpg.rf.b2fce8d40b229d62fc25ba293def973b.xml to 02170.xml
# Renamed: 22657_jpg.rf.fde0f33b8a5f893b57874c9a24a72994.jpg to 02171.jpg
# Renamed: 22657_jpg.rf.fde0f33b8a5f893b57874c9a24a72994.xml to 02171.xml
# Renamed: 22659_jpg.rf.35cd5363a45e0c5761227069492d2c86.jpg to 02172.jpg
# Renamed: 22659_jpg.rf.35cd5363a45e0c5761227069492d2c86.xml to 02172.xml
# Renamed: 22671_jpg.rf.a1eecde459744da986a8d0d1dd5669a4.jpg to 02173.jpg
# Renamed: 22671_jpg.rf.a1eecde459744da986a8d0d1dd5669a4.xml to 02173.xml
# Renamed: 22675_jpg.rf.d39ae780fd02c1488808f3919b58193f.jpg to 02174.jpg
# Renamed: 22675_jpg.rf.d39ae780fd02c1488808f3919b58193f.xml to 02174.xml
# Renamed: 22690_jpg.rf.d9c2b99913e0cc0573c2ec6a5da4e24c.jpg to 02175.jpg
# Renamed: 22690_jpg.rf.d9c2b99913e0cc0573c2ec6a5da4e24c.xml to 02175.xml
# Renamed: 22691_jpg.rf.a7d685f59d4ccfb02a24ad188ab42ab9.jpg to 02176.jpg
# Renamed: 22691_jpg.rf.a7d685f59d4ccfb02a24ad188ab42ab9.xml to 02176.xml
# Renamed: 22702_jpg.rf.497dbe1e230d3d459d9d29018af6498c.jpg to 02177.jpg
# Renamed: 22702_jpg.rf.497dbe1e230d3d459d9d29018af6498c.xml to 02177.xml
# Renamed: 22710_jpg.rf.7b687efc5b716a0a331e8a4381dafe11.jpg to 02178.jpg
# Renamed: 22710_jpg.rf.7b687efc5b716a0a331e8a4381dafe11.xml to 02178.xml
# Renamed: 22735_jpg.rf.6f9c36127fd56e42bc5ba0ae6a099dce.jpg to 02179.jpg
# Renamed: 22735_jpg.rf.6f9c36127fd56e42bc5ba0ae6a099dce.xml to 02179.xml
# Renamed: 22755_jpg.rf.44d6c72e29de841e10aeb14d0f0ad32b.jpg to 02180.jpg
# Renamed: 22755_jpg.rf.44d6c72e29de841e10aeb14d0f0ad32b.xml to 02180.xml
# Renamed: 22785_jpg.rf.f6170ed9d4365a3c5a7dd52a1a3aea51.jpg to 02181.jpg
# Renamed: 22785_jpg.rf.f6170ed9d4365a3c5a7dd52a1a3aea51.xml to 02181.xml
# Renamed: 22802_jpg.rf.1046ab8aa6c54d1f9f16cbed9da62089.jpg to 02182.jpg
# Renamed: 22802_jpg.rf.1046ab8aa6c54d1f9f16cbed9da62089.xml to 02182.xml
# Renamed: 22807_jpg.rf.e20e7d57e09121a7c7e5ab3969393791.jpg to 02183.jpg
# Renamed: 22807_jpg.rf.e20e7d57e09121a7c7e5ab3969393791.xml to 02183.xml
# Renamed: 22836_jpg.rf.aee2448e18b57ec879d7c6b9a6da7c70.jpg to 02184.jpg
# Renamed: 22836_jpg.rf.aee2448e18b57ec879d7c6b9a6da7c70.xml to 02184.xml
# Renamed: 22855_jpg.rf.7ec64adf6646ada491436693c8d8d775.jpg to 02185.jpg
# Renamed: 22855_jpg.rf.7ec64adf6646ada491436693c8d8d775.xml to 02185.xml
# Renamed: 22897_jpg.rf.e22c6cd1cf14c377c5c1240dfc2c7130.jpg to 02186.jpg
# Renamed: 22897_jpg.rf.e22c6cd1cf14c377c5c1240dfc2c7130.xml to 02186.xml
# Renamed: 22899_jpg.rf.5b62d51e6510dddc6157fd17f4f29265.jpg to 02187.jpg
# Renamed: 22899_jpg.rf.5b62d51e6510dddc6157fd17f4f29265.xml to 02187.xml
# Renamed: 22900_jpg.rf.702c9e1229d1e1fc73a5f5640701d24f.jpg to 02188.jpg
# Renamed: 22900_jpg.rf.702c9e1229d1e1fc73a5f5640701d24f.xml to 02188.xml
# Renamed: 22916_jpg.rf.17c8c7627bf9b590d6afbca37a2784e3.jpg to 02189.jpg
# Renamed: 22916_jpg.rf.17c8c7627bf9b590d6afbca37a2784e3.xml to 02189.xml
# Renamed: 22926_jpg.rf.9a5cd21a528a3558c463342af03122e8.jpg to 02190.jpg
# Renamed: 22926_jpg.rf.9a5cd21a528a3558c463342af03122e8.xml to 02190.xml
# Renamed: 22934_jpg.rf.c850fd539d5bbd72207b8f48b35a0f8d.jpg to 02191.jpg
# Renamed: 22934_jpg.rf.c850fd539d5bbd72207b8f48b35a0f8d.xml to 02191.xml
# Renamed: 22947_jpg.rf.480e6bf6620feb35bd6f396663e17425.jpg to 02192.jpg
# Renamed: 22947_jpg.rf.480e6bf6620feb35bd6f396663e17425.xml to 02192.xml
# Renamed: 22949_jpg.rf.ee297bb3b0fff2951c708c7a1892402c.jpg to 02193.jpg
# Renamed: 22949_jpg.rf.ee297bb3b0fff2951c708c7a1892402c.xml to 02193.xml
# Renamed: 22952_jpg.rf.68097a2083f13236ca92e395b3891463.jpg to 02194.jpg
# Renamed: 22952_jpg.rf.68097a2083f13236ca92e395b3891463.xml to 02194.xml
# Renamed: 22962_jpg.rf.0cf5cb9a0d88baa44fac645beef9f2d7.jpg to 02195.jpg
# Renamed: 22962_jpg.rf.0cf5cb9a0d88baa44fac645beef9f2d7.xml to 02195.xml
# Renamed: 22968_jpg.rf.667e45c876fa5a877d81903ff4cc242b.jpg to 02196.jpg
# Renamed: 22968_jpg.rf.667e45c876fa5a877d81903ff4cc242b.xml to 02196.xml
# Renamed: 22970_jpg.rf.5651c572c6d4b00f213aa60a6c5da91b.jpg to 02197.jpg
# Renamed: 22970_jpg.rf.5651c572c6d4b00f213aa60a6c5da91b.xml to 02197.xml
# Renamed: 22972_jpg.rf.cacd8c6bc892e54efa6919d37455d09b.jpg to 02198.jpg
# Renamed: 22972_jpg.rf.cacd8c6bc892e54efa6919d37455d09b.xml to 02198.xml
# Renamed: 22983_jpg.rf.25d278acfd60d797be08c2054a060428.jpg to 02199.jpg
# Renamed: 22983_jpg.rf.25d278acfd60d797be08c2054a060428.xml to 02199.xml
# Renamed: 22994_jpg.rf.07fbbb622d1888bb60d006e481afb267.jpg to 02200.jpg
# Renamed: 22994_jpg.rf.07fbbb622d1888bb60d006e481afb267.xml to 02200.xml
# Renamed: 23029_jpg.rf.2d73a45a0ebf08a647395e6f4e0c5067.jpg to 02201.jpg
# Renamed: 23029_jpg.rf.2d73a45a0ebf08a647395e6f4e0c5067.xml to 02201.xml
# Renamed: 23053_jpg.rf.62f9acca3caf958d17e4717f0673c591.jpg to 02202.jpg
# Renamed: 23053_jpg.rf.62f9acca3caf958d17e4717f0673c591.xml to 02202.xml
# Renamed: 23058_jpg.rf.63b63524ce1631316012bb249c3b6c34.jpg to 02203.jpg
# Renamed: 23058_jpg.rf.63b63524ce1631316012bb249c3b6c34.xml to 02203.xml
# Renamed: 23065_jpg.rf.fcdfe412f6800b7ccb53e029b2fb7f3f.jpg to 02204.jpg
# Renamed: 23065_jpg.rf.fcdfe412f6800b7ccb53e029b2fb7f3f.xml to 02204.xml
# Renamed: 23073_jpg.rf.9c05f30fa6a2fa96b0bbb53ba863dc3b.jpg to 02205.jpg
# Renamed: 23073_jpg.rf.9c05f30fa6a2fa96b0bbb53ba863dc3b.xml to 02205.xml
# Renamed: 23088_jpg.rf.bdbefc00ca71487efa7a8ad7ec37dcbb.jpg to 02206.jpg
# Renamed: 23088_jpg.rf.bdbefc00ca71487efa7a8ad7ec37dcbb.xml to 02206.xml
# Renamed: 23094_jpg.rf.1ca3777c920fdcdfaa1a3f2b3e78485e.jpg to 02207.jpg
# Renamed: 23094_jpg.rf.1ca3777c920fdcdfaa1a3f2b3e78485e.xml to 02207.xml
# Renamed: 23095_jpg.rf.6de29a6ea0f65dab2cffcd6a3992640e.jpg to 02208.jpg
# Renamed: 23095_jpg.rf.6de29a6ea0f65dab2cffcd6a3992640e.xml to 02208.xml
# Renamed: 23101_jpg.rf.7f3bbdee93a736e491b0c832552f11e5.jpg to 02209.jpg
# Renamed: 23101_jpg.rf.7f3bbdee93a736e491b0c832552f11e5.xml to 02209.xml
# Renamed: 23120_jpg.rf.bdb5be10728d2641e315cae30219055a.jpg to 02210.jpg
# Renamed: 23120_jpg.rf.bdb5be10728d2641e315cae30219055a.xml to 02210.xml
# Renamed: 23122_jpg.rf.abeac4175244c6c7c05358918ab2e7d7.jpg to 02211.jpg
# Renamed: 23122_jpg.rf.abeac4175244c6c7c05358918ab2e7d7.xml to 02211.xml

# %% [markdown]
# ### Convert XML labels to ESRI format
#
# this only currently works for one class in the labels

# %%
import fileinput
import sys

# Set your class name and values
class_name = 'Surfer'
class_value = '1'
class_name2 = 'Surfer standing'
class_value2 = '2'

# Iterate through each file in the directory
for filename in os.listdir(label_dir):
    if filename.endswith('.xml'):
        # Read in the contents of the file
        with fileinput.input(os.path.join(label_dir, filename), inplace=True) as f:
            for line in f:
                # Remove specified lines
                if '<path>' in line or '<pose>' in line or '<truncated>' in line or '<difficult>' in line or '<occluded>' in line or '<segmented>' in line:
                    continue
                # Replace specified text
                elif '<database>roboflow.ai</database>' in line:
                    sys.stdout.write(line.replace('<database>roboflow.ai</database>', '<annotation>ESRI ArcGIS Pro</annotation>'))
                # Replace Surfer with 1
                elif '<name>{}</name>'.format(class_name) in line:
                    sys.stdout.write(line.replace('<name>{}</name>'.format(class_name), '<name>{}</name>'.format(class_value)))
                # Replace Surfer standing with 2
                elif '<name>{}</name>'.format(class_name2) in line:
                    sys.stdout.write(line.replace('<name>{}</name>'.format(class_name2), '<name>{}</name>'.format(class_value2)))
                # Replace filename line with current filename
                elif '<filename>' in line:
                    new_filename = filename[:-4] + '.jpg'
                    sys.stdout.write(line.replace(line, '\t<filename>{}</filename>\n'.format(new_filename)))
                # Add specified line
                elif fileinput.isfirstline():
                    sys.stdout.write('<?xml version="1.0"?>\n')
                    sys.stdout.write(line)
                # Write the line as is
                else:
                    sys.stdout.write(line)

# %% [markdown]
# ### Create map.txt

# %%
# set output map.txt directory
out_map = os.path.join(labels_folder_name, 'map.txt')

image_dir_split = os.path.split(image_dir)
label_dir_split = os.path.split(label_dir)

# create a list of image and label files
image_files = sorted(os.listdir(image_dir))
label_files = sorted(os.listdir(label_dir))

# create a list of tuples with the image and label filenames
file_list = list(zip(image_files, label_files))

# create a text file and write the file paths to it
with open(out_map, 'w') as f:
    for image_file, label_file in file_list:
        image_path = os.path.join(image_dir_split[-1], image_file)
        label_path = os.path.join(label_dir_split[-1], label_file)
        line = f"{image_path}  {label_path}\n"
        f.write(line)

# %% [markdown]
# ### Calculate stats.txt file

# %%
import xml.etree.ElementTree as ET

IMAGE_DIR = image_dir
ANNOT_DIR = label_dir
STATS_FILE = os.path.join(labels_folder_name , "stats.txt")

IMAGE_WIDTH = 640
IMAGE_HEIGHT = 540
NUM_CLASSES = 2
CLASS_NAMES = ["Surfer", "Surfer standing"]  # change this if you have multiple classes

# initialize stats
num_images = 0
num_features = 0
min_features_per_image = float("inf")
max_features_per_image = float("-inf")
total_features_per_image = 0
min_width = float("inf")
max_width = float("-inf")
min_height = float("inf")
max_height = float("-inf")
total_width = 0
total_height = 0

# loop through each image file in the directory
image_iteration = 0
for image_filename in os.listdir(IMAGE_DIR):
    if image_filename.endswith(".jpg"):
        num_images += 1
        image_path = os.path.join(IMAGE_DIR, image_filename)
        image_width = IMAGE_WIDTH
        image_height = IMAGE_HEIGHT

        # loop through each annotation file and count the number of features
        num_features_in_image = 0
        for annot_filename in os.listdir(ANNOT_DIR):
            
            if annot_filename.endswith(".xml"):
                annot_path = os.path.join(ANNOT_DIR, annot_filename)
                tree = ET.parse(annot_path)
                root = tree.getroot()
                if root.find("filename").text == image_filename:
                    for obj in root.iter("object"):
                        class_name = obj.find("name").text
                        if class_name not in CLASS_NAMES:
                            CLASS_NAMES.append(class_name)
                            NUM_CLASSES += 1
                        num_features += 1
                        num_features_in_image += 1
                        bbox = obj.find("bndbox")
                        xmin = float(bbox.find("xmin").text)
                        ymin = float(bbox.find("ymin").text)
                        xmax = float(bbox.find("xmax").text)
                        ymax = float(bbox.find("ymax").text)
                        width = xmax - xmin
                        height = ymax - ymin
                        total_width += width
                        total_height += height
                        if width < min_width:
                            min_width = width
                        if width > max_width:
                            max_width = width
                        if height < min_height:
                            min_height = height
                        if height > max_height:
                            max_height = height

        if num_features_in_image < min_features_per_image:
            min_features_per_image = num_features_in_image
        if num_features_in_image > max_features_per_image:
            max_features_per_image = num_features_in_image
        total_features_per_image += num_features_in_image
    
    print('Image iteration: ' , image_iteration)
    image_iteration += 1
# calculate stats
mean_features_per_image = total_features_per_image / num_images
mean_width = total_width / num_features
mean_height = total_height / num_features


# write stats to file
with open(STATS_FILE, "w") as f:
    f.write("images = {} *{}*{}*{}\n".format(num_images, NUM_CLASSES, IMAGE_WIDTH, IMAGE_HEIGHT))
    f.write("\nClass feature statistics:\n")
    f.write("features = {}\n".format(num_features))
    f.write("features per image = [min = {}, mean = {:.2f}, max = {}]\n".format(
        min_features_per_image, mean_features_per_image, max_features_per_image))
    f.write("classes = {}\n".format(NUM_CLASSES))
    f.write("{:<40} {:<12} {:<8} {:<12} {:<12} {:<12} {:<12}\n".format(
        "cls name", "cls value", "images", "features", "min size", "mean size", "max size"))
    for i, cls_name in enumerate(CLASS_NAMES):
        f.write("{:<40} {:<12} {:<8} {:<12} {:<12.2f} {:<12.2f} {:<12.2f}\n".format(
            cls_name, i+1, num_images, num_features, min_width, mean_width, max_width))

# %% [markdown]
# ### now need to add the .emd file and the esri accumulated stats
#
# maybe create a download link to a template or keep it linked to the notebook

# %%
import xml.etree.ElementTree as ET

ANNOTATION_FOLDER = label_dir
IMAGE_FOLDER = image_dir

# Function to calculate area of a bounding box
def calculate_area(box):
    return (box[2] - box[0]) * (box[3] - box[1])

# Initialize variables for calculating stats
min_area = float('inf')
max_area = 0
total_area = 0
count = 0

xml_iteration = 0
# Loop through each annotation file
for filename in os.listdir(ANNOTATION_FOLDER):
    if not filename.endswith('.xml'):
        continue
    tree = ET.parse(os.path.join(ANNOTATION_FOLDER, filename))
    root = tree.getroot()
    # Loop through each bounding box in the annotation file
    for box in root.findall('.//bndbox'):
        xmin = int(box.find('xmin').text)
        ymin = int(box.find('ymin').text)
        xmax = int(box.find('xmax').text)
        ymax = int(box.find('ymax').text)
        area = calculate_area([xmin, ymin, xmax, ymax])

        # Update stats
        min_area = min(min_area, area)
        max_area = max(max_area, area)
        total_area += area
        count += 1
    print("\rReading Annotation File: %d" % xml_iteration, end="")
    xml_iteration += 1
print('Read all files')
# Calculate mean area
mean_area = total_area / count if count != 0 else 0

# Print stats
print(f"Min area: {min_area}")
print(f"Max area: {max_area}")
print(f"Mean area: {mean_area}")
print(f"Total area: {total_area}")
print(f"Number of bounding boxes: {count}")
# Out:
# Reading Annotation File: 2210Read all files
# Min area: 195
# Max area: 7968
# Mean area: 1852.256514310124
# Total area: 8672265
# Number of bounding boxes: 4682

# %% [markdown]
# ### Generate stats
#
# Use these Cells to help produce the information required for these esri files:
#
#     - stats.txt
#     - esri_accumulated_stas.json
#     - esri_model_definition.emd

# %% [markdown]
# #### All stats

# %%
import xml.etree.ElementTree as ET

ANNOTATION_FOLDER = label_dir

# Function to calculate area of a bounding box
def calculate_area(box):
    return (box[2] - box[0]) * (box[3] - box[1])

# Initialize variables for calculating stats
min_area = float('inf')
max_area = 0
total_area = 0
count = 0
annotated_files = 0
total_annotation_files = 0
min_annotations = float('inf')  # Variable to track minimum number of annotations in a file
max_annotations = 0  # Variable to track maximum number of annotations in a file
total_annotations = 0  # Variable to track total number of annotations

class_labels = set()  # Set to store unique class labels

xml_iteration = 0
# Loop through each annotation file
for filename in os.listdir(ANNOTATION_FOLDER):
    if not filename.endswith('.xml'):
        continue
    tree = ET.parse(os.path.join(ANNOTATION_FOLDER, filename))
    root = tree.getroot()

    # Check if the file has annotations
    if len(root.findall('.//bndbox')) > 0:
        annotated_files += 1

    # Increment total_annotation_files for each XML file encountered
    total_annotation_files += 1
    
    num_annotations = len(root.findall('.//bndbox'))

    # Update min_annotations and max_annotations
    if num_annotations < min_annotations:
        min_annotations = num_annotations
    if num_annotations > max_annotations:
        max_annotations = num_annotations
        xml_with_max_annotations = filename

    # Loop through each bounding box in the annotation file
    for box in root.findall('.//bndbox'):
        xmin = int(box.find('xmin').text)
        ymin = int(box.find('ymin').text)
        xmax = int(box.find('xmax').text)
        ymax = int(box.find('ymax').text)
        
        # Check if the <name> tag exists
        if box.find('name') is not None and box.find('name').text is not None:
            class_label = int(box.find('name').text)
            class_labels.add(class_label)

        area = calculate_area([xmin, ymin, xmax, ymax])

        # Update stats
        min_area = min(min_area, area)
        max_area = max(max_area, area)
        total_area += area
        count += 1

    total_annotations += num_annotations
    print("\rReading Annotation File: %d" % xml_iteration, end="")
    xml_iteration += 1
print('   Read all files')

# Calculate mean area
mean_area = total_area / count if count != 0 else 0

# Calculate mean number of annotations per file
mean_annotations = total_annotations / total_annotation_files if total_annotation_files != 0 else 0

# Print stats
print(f"Min area: {min_area}")
print(f"Max area: {max_area}")
print(f"Mean area: {mean_area}")
print(f"Total area: {total_area}")
print(f"Number of bounding boxes: {count}")
print(f"Number of files with annotations: {annotated_files}")
print(f"Total number of annotation files: {total_annotation_files}")
print(f"Min annotations per file: {min_annotations}")
print(f"Max annotations per file: {max_annotations}")
print(f"Mean annotations per file: {mean_annotations}")
print(f"XML file with the highest number of annotations: {xml_with_max_annotations}")
print(f"Unique class labels: {class_labels}")
# Out:
# Reading Annotation File: 2210   Read all files
# Min area: 195
# Max area: 7968
# Mean area: 1852.256514310124
# Total area: 8672265
# Number of bounding boxes: 4682
# Number of files with annotations: 1671
# Total number of annotation files: 2211
# Min annotations per file: 0
# Max annotations per file: 10
# Mean annotations per file: 2.1175938489371324
# XML file with the highest number of annotations: 01971.xml
# Unique class labels: set()

# %% [markdown]
# #### Class Stats
#
# change the value in the class_label_value parameter to calculate for the different classes

# %%
# Function to calculate area of a bounding box
def calculate_area(box):
    return (box[2] - box[0]) * (box[3] - box[1])

# Initialize variables for calculating stats

class_label_value = '1'  ###CHANGE THIS ONE FOR DIFFERENT CLASSES AND REPEAT
min_area = float('inf')
max_area = 0
total_area = 0
count = 0
annotated_files = 0
total_annotation_files = 0
min_annotations = float('inf')  # Variable to track minimum number of annotations in a file
max_annotations = 0  # Variable to track maximum number of annotations in a file
total_annotations = 0  # Variable to track total number of annotations
class_annotation_files = 0  # Variable to track the number of annotation files for the class


xml_iteration = 0
# Loop through each annotation file
for filename in os.listdir(ANNOTATION_FOLDER):
    if not filename.endswith('.xml'):
        continue
    tree = ET.parse(os.path.join(ANNOTATION_FOLDER, filename))
    root = tree.getroot()

    # Check if the file has annotations
    if len(root.findall('.//bndbox')) > 0:
        annotated_files += 1

    # Increment total_annotation_files for each XML file encountered
    total_annotation_files += 1
    
    num_annotations = 0
    class_num_annotations = 0 

    # Loop through each bounding box in the annotation file
    for box in root.findall('.//object'):
        # Check if the class label is 1
        if box.find('name').text == class_label_value:
            xmin = int(box.find('bndbox/xmin').text)
            ymin = int(box.find('bndbox/ymin').text)
            xmax = int(box.find('bndbox/xmax').text)
            ymax = int(box.find('bndbox/ymax').text)
            area = calculate_area([xmin, ymin, xmax, ymax])

            # Update stats
            min_area = min(min_area, area)
            max_area = max(max_area, area)
            total_area += area
            count += 1
            num_annotations += 1
            class_num_annotations += 1

    # Update min_annotations and max_annotations
    if num_annotations < min_annotations:
        min_annotations = num_annotations
    if num_annotations > max_annotations:
        max_annotations = num_annotations
        xml_with_max_annotations = filename

    if class_num_annotations > 0:
        class_annotation_files += 1 

    print("\rReading Annotation File: %d" % xml_iteration, end="")
    xml_iteration += 1

print('   Read all files')

# Calculate mean area
mean_area = total_area / count if count != 0 else 0

# Calculate mean number of annotations per file
mean_annotations = total_annotations / total_annotation_files if total_annotation_files != 0 else 0

# Print stats
print("Class ", class_label_value , " Stats:")
print(" ")
print("Area: ")
print(f"    Min area: {min_area}")
print(f"    Max area: {max_area}")
print(f"    Mean area: {mean_area}")
print(f"    Total area: {total_area}")
print(" ")
print("Annotations: ")
print(f"    Number of bounding boxes: {count}")
print(f"    Number of files with annotations: {annotated_files}")
print(f"    Total number of annotation files: {total_annotation_files}")
print(f"    Number of annotation files for Class {class_label_value}: {class_annotation_files}")
print(f"    Min annotations per file: {min_annotations}")
print(f"    Max annotations per file: {max_annotations}")
print(f"    Mean annotations per file: {mean_annotations}")
print(" ")
print(f"XML file with the highest number of annotations: {xml_with_max_annotations}")
# Out:
# Reading Annotation File: 2210   Read all files
# Class  1  Stats:
#
# Area:
#     Min area: 195
#     Max area: 5796
#     Mean area: 1842.3662469626684
#     Total area: 8340392
#
# Annotations:
#     Number of bounding boxes: 4527
#     Number of files with annotations: 1671
#     Total number of annotation files: 2211
#     Number of annotation files for Class 1: 1602
#     Min annotations per file: 0
#     Max annotations per file: 10
#     Mean annotations per file: 0.0
#
# XML file with the highest number of annotations: 01971.xml
